# %%
import time
import re, string
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as pat
import pandas as pd
from collections import Counter
from random import randint

import scipy as sp
import scipy.cluster
import scipy.cluster.hierarchy as hierarchy
import scipy.spatial.distance

from sklearn.cluster import KMeans
import sklearn.datasets as sk_data
import sklearn.metrics as metrics
from sklearn import mixture
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.utils.extmath import randomized_svd

#import matplotlib as mpl
import seaborn as sns

import nltk
#nltk.download()
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
# %matplotlib inline

matplotlib_colors = ['b', 'g', 'r', 'c', 'm', 'grey', 'y', 'orange', 'pink', 'mediumspringgreen', 'darkcyan', 'darkviolet', 'darkslateblue', 'darkslategrey', 'skyblue', 'lime','indianred','maroon','darkolivegreen','dodgerblue']

# %% [markdown]
# # Generating Training and Test Cases

# %%
MA_Data = pd.read_pickle('Massachusetts.pkl')

# %%
MA_Data_Shuffle = MA_Data.sample(frac=1)
MA_Data_Shuffle = MA_Data_Shuffle.reset_index()
MA_Data_Shuffle = MA_Data_Shuffle.rename(columns = {'index':'original_index'})
MA_Data_Shuffle
# Out:
#       original_index State           Station Name (LEA)               NSN  \
# 0                 61    MA   CENTRAL MA LAW ENFORCEMENT  1005-00-589-1271
# 1                203    MA       FRAMINGHAM POLICE DEPT  1005-00-073-9421
# 2               1005    MA       SOMERVILLE POLICE DEPT  1005-00-856-6885
# 3                630    MA           MILTON POLICE DEPT  5855-01-228-0937
# 4                229    MA       GLOUCESTER POLICE DEPT  5855-01-228-0939
# 5                953    MA         SOMERSET POLICE DEPT  1005-00-589-1271
# 6                737    MA           NORTON POLICE DEPT  1005-00-073-9421
# 7                558    MA           MILTON POLICE DEPT  1005-00-589-1271
# 8               1198    MA          WAREHAM POLICE DEPT  5360-00-992-6652
# 9                429    MA        MANSFIELD POLICE DEPT  1005-00-073-9421
# 10              1145    MA          WAREHAM POLICE DEPT  1005-01-382-6795
# 11               695    MA      NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 12               837    MA           REVERE POLICE DEPT  1240-01-540-3763
# 13               310    MA          HARWICH POLICE DEPT  1005-00-073-9421
# 14              1097    MA        TOPSFIELD POLICE DEPT  1005-00-073-9421
# 15                57    MA   CENTRAL MA LAW ENFORCEMENT  1005-00-589-1271
# 16               629    MA           MILTON POLICE DEPT  1240-01-411-1265
# 17              1134    MA          WALPOLE POLICE DEPT  1005-00-589-1271
# 18              1286    MA   WESTPORT POLICE DEPARTMENT  5855-01-447-8992
# 19               273    MA           GROTON POLICE DEPT  1005-00-856-6885
# 20              1036    MA      SOUTHBRIDGE POLICE DEPT  1005-00-856-6885
# 21               711    MA      NEW BEDFORD POLICE DEPT  2355-01-562-6146
# 22              1161    MA          WAREHAM POLICE DEPT  5360-00-979-3931
# 23              1244    MA  WEST BROOKFIELD POLICE DEPT  1005-00-726-5655
# 24               707    MA      NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 25               449    MA       MARSHFIELD POLICE DEPT  2320-01-380-8604
# 26               584    MA           MILTON POLICE DEPT  5855-01-468-4169
# 27               467    MA          MEDFORD POLICE DEPT  1005-00-073-9421
# 28               985    MA         SOMERSET POLICE DEPT  1005-00-999-1509
# 29               247    MA       GLOUCESTER POLICE DEPT  5855-01-228-0939
# ...              ...   ...                          ...               ...
# 1279            1284    MA   WESTPORT POLICE DEPARTMENT  2320-01-107-7155
# 1280             233    MA       GLOUCESTER POLICE DEPT  8415-01-394-5401
# 1281             828    MA           REVERE POLICE DEPT  8475-00-420-6361
# 1282            1141    MA          WAREHAM POLICE DEPT  1005-01-233-8531
# 1283            1173    MA          WAREHAM POLICE DEPT  5305-01-484-7075
# 1284            1121    MA     TYNGSBOROUGH POLICE DEPT  2815-01-246-0903
# 1285             294    MA           HADLEY POLICE DEPT  1005-00-726-5655
# 1286            1138    MA          WAREHAM POLICE DEPT  1005-01-453-4227
# 1287              51    MA  BRISTOL COUNTY SHERIFF DEPT  1005-00-589-1271
# 1288             419    MA             LYNN POLICE DEPT  1005-01-128-9936
# 1289             867    MA           REVERE POLICE DEPT  5855-00-629-5327
# 1290              36    MA       BARNSTABLE POLICE DEPT  1005-00-589-1271
# 1291              35    MA           AUBURN POLICE DEPT  1005-00-073-9421
# 1292             299    MA           HANSON POLICE DEPT  1005-00-589-1271
# 1293             442    MA       MARSHFIELD POLICE DEPT  2320-01-107-7155
# 1294             598    MA           MILTON POLICE DEPT  5855-01-468-4169
# 1295             155    MA          DUXBURY POLICE DEPT  1005-00-073-9421
# 1296             414    MA           LEYDEN POLICE DEPT  4910-01-503-3086
# 1297             124    MA           DHS/ICE/HSI BOSTON  6510-01-541-8121
# 1298            1102    MA     TYNGSBOROUGH POLICE DEPT  1005-01-128-9936
# 1299            1292    MA   WESTPORT POLICE DEPARTMENT  5855-01-447-8992
# 1300            1021    MA      SOUTHBRIDGE POLICE DEPT  1005-00-856-6885
# 1301             421    MA             LYNN POLICE DEPT  1005-01-128-9936
# 1302              66    MA    CHATHAM POLICE DEPARTMENT  2320-01-107-7153
# 1303             318    MA        HAVERHILL POLICE DEPT  2355-01-553-4634
# 1304             524    MA          METHUEN POLICE DEPT  1005-00-073-9421
# 1305             420    MA             LYNN POLICE DEPT  1005-01-128-9936
# 1306             744    MA           NORTON POLICE DEPT  1005-00-073-9421
# 1307             726    MA      NORTHBRIDGE POLICE DEPT  1005-00-589-1271
# 1308             606    MA           MILTON POLICE DEPT  5855-01-468-4169
#
#                                    Item Name  Quantity    UI  \
# 0                      RIFLE,7.62 MILLIMETER         1  Each
# 1                      RIFLE,5.56 MILLIMETER         1  Each
# 2                      RIFLE,5.56 MILLIMETER         1  Each
# 3                        NIGHT VISION GOGGLE         1  Each
# 4                        NIGHT VISION GOGGLE         1  Each
# 5                      RIFLE,7.62 MILLIMETER         1  Each
# 6                      RIFLE,5.56 MILLIMETER         1  Each
# 7                      RIFLE,7.62 MILLIMETER         1  Each
# 8                 SPRING,HELICAL,COMPRESSION        10  Each
# 9                      RIFLE,5.56 MILLIMETER         1  Each
# 10                        RECEIVER,CARTRIDGE         1  Each
# 11                     RIFLE,5.56 MILLIMETER         1  Each
# 12                     TELESCOPE SUBASSEMBLY        11  Each
# 13                     RIFLE,5.56 MILLIMETER         1  Each
# 14                     RIFLE,5.56 MILLIMETER         1  Each
# 15                     RIFLE,7.62 MILLIMETER         1  Each
# 16                              SIGHT,REFLEX         2  Each
# 17                     RIFLE,7.62 MILLIMETER         1  Each
# 18                      ILLUMINATOR,INFRARED         1  Each
# 19                     RIFLE,5.56 MILLIMETER         1  Each
# 20                     RIFLE,5.56 MILLIMETER         1  Each
# 21                    MINE RESISTANT VEHICLE         1  Each
# 22                SPRING,HELICAL,COMPRESSION        10  Each
# 23              PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 24                     RIFLE,5.56 MILLIMETER         1  Each
# 25                             TRUCK,UTILITY         1  Each
# 26                      ILLUMINATOR,INFRARED         1  Each
# 27                     RIFLE,5.56 MILLIMETER         1  Each
# 28                   PIN,FIRING PIN RETAINER        20  Each
# 29                       NIGHT VISION GOGGLE         1  Each
# ...                                      ...       ...   ...
# 1279                           TRUCK,UTILITY         1  Each
# 1280                             HOOD,FLYERS        20  Each
# 1281                     HOOD,PROTECTIVE,ANT        30  Each
# 1282                     EXTENSION,LOWER             4  Each
# 1283                  SCREW,CAP,HEXAGON HEAD        10  Each
# 1284                     ENGINE,W CONTAINER          1  Each
# 1285            PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 1286                     HANDGUARD,UPPER             2  Each
# 1287                   RIFLE,7.62 MILLIMETER         1  Each
# 1288                   RIFLE,5.56 MILLIMETER         1  Each
# 1289  NIGHT VISION SIGHT CREW SERVED WEAPONS         1  Each
# 1290                   RIFLE,7.62 MILLIMETER         1  Each
# 1291                   RIFLE,5.56 MILLIMETER         1  Each
# 1292                   RIFLE,7.62 MILLIMETER         1  Each
# 1293                           TRUCK,UTILITY         1  Each
# 1294                    ILLUMINATOR,INFRARED         1  Each
# 1295                   RIFLE,5.56 MILLIMETER         1  Each
# 1296                      LIFT,MOTOR VEHICLE         1  Each
# 1297                     BANDAGE,ABDOMINAL          99  Each
# 1298                   RIFLE,5.56 MILLIMETER         1  Each
# 1299                    ILLUMINATOR,INFRARED         1  Each
# 1300                   RIFLE,5.56 MILLIMETER         1  Each
# 1301                   RIFLE,5.56 MILLIMETER         1  Each
# 1302                           TRUCK,UTILITY         1  Each
# 1303                  MINE RESISTANT VEHICLE         1  Each
# 1304                   RIFLE,5.56 MILLIMETER         1  Each
# 1305                   RIFLE,5.56 MILLIMETER         1  Each
# 1306                   RIFLE,5.56 MILLIMETER         1  Each
# 1307                   RIFLE,7.62 MILLIMETER         1  Each
# 1308                    ILLUMINATOR,INFRARED         1  Each
#
#       Acquisition Value DEMIL Code  DEMIL IC  Ship Date
# 0                138.00          D       1.0 2006-09-07
# 1                499.00          D       1.0 1998-12-21
# 2                120.00          D       1.0 2011-09-26
# 3               3578.00          F       1.0 2012-01-23
# 4               6000.00          F       1.0 2012-01-18
# 5                138.00          D       1.0 2005-08-18
# 6                499.00          D       1.0 2012-04-17
# 7                138.00          D       1.0 2011-12-29
# 8                  0.07          B       3.0 2014-08-21
# 9                499.00          D       1.0 1998-12-01
# 10                87.96          D       1.0 2014-08-21
# 11               499.00          D       1.0 2012-01-17
# 12               110.06          D       1.0 2011-10-07
# 13               499.00          D       1.0 2004-05-03
# 14               499.00          D       1.0 2002-09-09
# 15               138.00          D       1.0 2006-09-07
# 16               315.00          D       1.0 2010-08-19
# 17               138.00          D       1.0 2001-02-14
# 18              1038.00          D       1.0 2011-07-15
# 19               120.00          D       1.0 2011-10-19
# 20               120.00          D       1.0 2011-10-26
# 21            689000.00          C       1.0 2014-03-28
# 22                 0.27          B       3.0 2013-10-24
# 23                58.71          D       1.0 2002-04-25
# 24               499.00          D       1.0 2012-01-17
# 25             81226.00          C       1.0 2011-11-09
# 26               776.79          D       1.0 2012-07-18
# 27               499.00          D       1.0 2006-02-21
# 28                 0.64          B       3.0 2011-11-09
# 29              6000.00          F       1.0 2012-01-18
# ...                 ...        ...       ...        ...
# 1279           41061.00          Q       6.0 2011-09-16
# 1280              54.60          E       1.0 2012-01-18
# 1281              22.92          B       3.0 2011-06-23
# 1282              50.65          D       1.0 2015-03-30
# 1283               2.90          B       3.0 2013-02-19
# 1284           26234.00          C       1.0 2012-10-26
# 1285              58.71          D       1.0 2011-10-19
# 1286              60.46          B       3.0 2013-10-24
# 1287             138.00          D       1.0 2003-06-21
# 1288             749.00          D       1.0 2014-11-24
# 1289            3433.00          F       1.0 2011-02-12
# 1290             138.00          D       1.0 1994-01-14
# 1291             499.00          D       1.0 2012-04-11
# 1292             138.00          D       1.0 2000-03-20
# 1293           41061.00          Q       6.0 2011-12-15
# 1294             776.79          D       1.0 2012-07-18
# 1295             499.00          D       1.0 2008-01-22
# 1296           24070.00          A       7.0 2017-01-30
# 1297              13.42          A       1.0 2017-03-22
# 1298             749.00          D       1.0 2014-12-01
# 1299            1038.00          D       1.0 2011-07-15
# 1300             120.00          D       1.0 2011-10-26
# 1301             749.00          D       1.0 2014-11-24
# 1302           63894.00          C       1.0 2010-09-13
# 1303          658000.00          C       1.0 2014-01-30
# 1304             499.00          D       1.0 2008-07-29
# 1305             749.00          D       1.0 2014-11-24
# 1306             499.00          D       1.0 2012-04-17
# 1307             138.00          D       1.0 2003-06-25
# 1308             776.79          D       1.0 2012-07-18
#
# [1309 rows x 11 columns]

# %%
Master_training = MA_Data_Shuffle.sample(round(len(MA_Data_Shuffle)*2/3), replace=False)
Master_training
# Out:
#       original_index State            Station Name (LEA)               NSN  \
# 902             1219    MA         WATERTOWN POLICE DEPT  1005-00-589-1271
# 44               683    MA       NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 1189             807    MA               REHOBOTH POLICE  2355-01-553-4634
# 37               743    MA            NORTON POLICE DEPT  1005-00-589-1271
# 27               467    MA           MEDFORD POLICE DEPT  1005-00-073-9421
# 193             1029    MA       SOUTHBRIDGE POLICE DEPT  1005-00-726-5655
# 1057             659    MA            MONSON POLICE DEPT  1005-00-589-1271
# 824             1050    MA        STURBRIDGE POLICE DEPT  1005-01-128-9936
# 472              669    MA       NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 22              1161    MA           WAREHAM POLICE DEPT  5360-00-979-3931
# 789              836    MA            REVERE POLICE DEPT  8475-01-311-9630
# 553              605    MA            MILTON POLICE DEPT  5855-01-468-4169
# 208               90    MA           CLINTON POLICE DEPT  1240-01-411-1265
# 1242            1225    MA           WEBSTER POLICE DEPT  1005-00-073-9421
# 647             1287    MA    WESTPORT POLICE DEPARTMENT  5855-01-447-8992
# 696              355    MA           IPSWICH POLICE DEPT  1240-01-411-1265
# 657              824    MA            REVERE POLICE DEPT  1005-00-726-5655
# 1187             777    MA  PLYMOUTH COUNTY SHERIFF DEPT  2520-01-474-7051
# 1127             180    MA         FAIRHAVEN POLICE DEPT  1005-00-073-9421
# 615              176    MA         FAIRHAVEN POLICE DEPT  1005-00-073-9421
# 850              529    MA           METHUEN POLICE DEPT  1005-01-484-8000
# 1077            1280    MA    WESTPORT POLICE DEPARTMENT  1005-00-073-9421
# 91                65    MA          CHARLTON POLICE DEPT  1005-00-073-9421
# 156              577    MA            MILTON POLICE DEPT  5855-01-468-4169
# 514              567    MA            MILTON POLICE DEPT  5855-01-468-4169
# 924              842    MA            REVERE POLICE DEPT  5855-00-629-5327
# 869              551    MA           MILFORD POLICE DEPT  1005-00-589-1271
# 659              225    MA        GLOUCESTER POLICE DEPT  5855-01-228-0939
# 239               31    MA            AUBURN POLICE DEPT  1005-00-073-9421
# 1197             484    MA           MEDFORD POLICE DEPT  1005-00-921-5483
# ...              ...   ...                           ...               ...
# 116              416    MA              LYNN POLICE DEPT  1005-01-128-9936
# 656             1058    MA        SWAMPSCOTT POLICE DEPT  1005-00-589-1271
# 633              808    MA               REHOBOTH POLICE  1005-00-073-9421
# 173              508    MA           METHUEN POLICE DEPT  1005-00-589-1271
# 266             1090    MA         TEMPLETON POLICE DEPT  1005-00-073-9421
# 167             1140    MA           WAREHAM POLICE DEPT  1005-01-233-8529
# 299               12    MA            AUBURN POLICE DEPT  1005-00-726-5655
# 75               428    MA         MANSFIELD POLICE DEPT  1005-00-073-9421
# 885              422    MA              LYNN POLICE DEPT  1005-01-128-9936
# 79               163    MA           EVERETT POLICE DEPT  1005-00-589-1271
# 1176             177    MA         FAIRHAVEN POLICE DEPT  1005-00-073-9421
# 88               251    MA           GRAFTON POLICE DEPT  1005-00-073-9421
# 1091             466    MA           MBTA TRANSIT POLICE  1005-00-073-9421
# 1196             909    MA             SALEM POLICE DEPT  1005-00-589-1271
# 977               76    MA           CHELSEA POLICE DEPT  1005-01-128-9936
# 816             1028    MA       SOUTHBRIDGE POLICE DEPT  1005-00-073-9421
# 477              857    MA            REVERE POLICE DEPT  1005-00-726-5655
# 114             1228    MA         WELLESLEY POLICE DEPT  8465-01-465-2144
# 865               37    MA        BARNSTABLE POLICE DEPT  5855-01-034-3845
# 467              966    MA          SOMERSET POLICE DEPT  1005-00-589-1271
# 1085            1150    MA           WAREHAM POLICE DEPT  1005-01-484-8000
# 469             1119    MA      TYNGSBOROUGH POLICE DEPT  1005-00-311-5394
# 399              323    MA    HINSDALE POLICE DEPARTMENT  1005-00-856-6885
# 228             1260    MA   WESTFIELD POLICE DEPARTMENT  1005-00-073-9421
# 950              736    MA            NORTON POLICE DEPT  1005-00-589-1271
# 881             1297    MA    WESTPORT POLICE DEPARTMENT  5855-01-447-8992
# 276              374    MA          LAWRENCE POLICE DEPT  1005-00-073-9421
# 586              395    MA         LEXINGTON POLICE DEPT  1005-00-073-9421
# 133             1153    MA           WAREHAM POLICE DEPT  1005-00-073-9421
# 699             1091    MA         TEMPLETON POLICE DEPT  1005-00-589-1271
#
#                                    Item Name  Quantity    UI  \
# 902                    RIFLE,7.62 MILLIMETER         1  Each
# 44                     RIFLE,5.56 MILLIMETER         1  Each
# 1189                  MINE RESISTANT VEHICLE         1  Each
# 37                     RIFLE,7.62 MILLIMETER         1  Each
# 27                     RIFLE,5.56 MILLIMETER         1  Each
# 193             PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 1057                   RIFLE,7.62 MILLIMETER         1  Each
# 824                    RIFLE,5.56 MILLIMETER         1  Each
# 472                    RIFLE,5.56 MILLIMETER         1  Each
# 22                SPRING,HELICAL,COMPRESSION        10  Each
# 789                      VISOR,FLYERS HELMET         4  Each
# 553                     ILLUMINATOR,INFRARED         1  Each
# 208                             SIGHT,REFLEX         5  Each
# 1242                   RIFLE,5.56 MILLIMETER         1  Each
# 647                     ILLUMINATOR,INFRARED         1  Each
# 696                             SIGHT,REFLEX         1  Each
# 657             PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 1187        TRANSMISSION,HYDRAULIC,VEHICULAR         1  Each
# 1127                   RIFLE,5.56 MILLIMETER         1  Each
# 615                    RIFLE,5.56 MILLIMETER         1  Each
# 850                               SIGHT,REAR        10  Each
# 1077                   RIFLE,5.56 MILLIMETER         1  Each
# 91                     RIFLE,5.56 MILLIMETER         1  Each
# 156                     ILLUMINATOR,INFRARED         1  Each
# 514                     ILLUMINATOR,INFRARED         1  Each
# 924   NIGHT VISION SIGHT CREW SERVED WEAPONS         1  Each
# 869                    RIFLE,7.62 MILLIMETER         1  Each
# 659                      NIGHT VISION GOGGLE         1  Each
# 239                    RIFLE,5.56 MILLIMETER         1  Each
# 1197               SHOTGUN,12 GAGE,RIOT TYPE         1  Each
# ...                                      ...       ...   ...
# 116                    RIFLE,5.56 MILLIMETER         1  Each
# 656                    RIFLE,7.62 MILLIMETER         1  Each
# 633                    RIFLE,5.56 MILLIMETER         1  Each
# 173                    RIFLE,7.62 MILLIMETER         1  Each
# 266                    RIFLE,5.56 MILLIMETER         1  Each
# 167          BARREL AND FRONT SIGHT ASSEMBLY         2  Each
# 299             PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 75                     RIFLE,5.56 MILLIMETER         1  Each
# 885                    RIFLE,5.56 MILLIMETER         1  Each
# 79                     RIFLE,7.62 MILLIMETER         1  Each
# 1176                   RIFLE,5.56 MILLIMETER         1  Each
# 88                     RIFLE,5.56 MILLIMETER         1  Each
# 1091                   RIFLE,5.56 MILLIMETER         1  Each
# 1196                   RIFLE,7.62 MILLIMETER         1  Each
# 977                    RIFLE,5.56 MILLIMETER         1  Each
# 816                    RIFLE,5.56 MILLIMETER         1  Each
# 477             PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 114         POUCH,BANDOLEER AMMO,6 MAGAZINES         1  Each
# 865      IMAGE INTENSIFIER TUBE,NIGHT VISION         9  Each
# 467                    RIFLE,7.62 MILLIMETER         1  Each
# 1085                              SIGHT,REAR         2  Each
# 469                      TOOL,BORE ALIGNMENT         1  Each
# 399                    RIFLE,5.56 MILLIMETER         1  Each
# 228                    RIFLE,5.56 MILLIMETER         1  Each
# 950                    RIFLE,7.62 MILLIMETER         1  Each
# 881                     ILLUMINATOR,INFRARED         1  Each
# 276                    RIFLE,5.56 MILLIMETER         1  Each
# 586                    RIFLE,5.56 MILLIMETER         1  Each
# 133                    RIFLE,5.56 MILLIMETER         1  Each
# 699                    RIFLE,7.62 MILLIMETER         1  Each
#
#       Acquisition Value DEMIL Code  DEMIL IC  Ship Date
# 902              138.00          D       1.0 1999-12-27
# 44               499.00          D       1.0 2012-01-17
# 1189          658000.00          C       1.0 2014-01-30
# 37               138.00          D       1.0 2011-12-30
# 27               499.00          D       1.0 2006-02-21
# 193               58.71          D       1.0 2011-11-30
# 1057             138.00          D       1.0 1999-04-07
# 824              749.00          D       1.0 2014-09-22
# 472              499.00          D       1.0 2012-01-17
# 22                 0.27          B       3.0 2013-10-24
# 789              114.55          B       3.0 2011-08-26
# 553              776.79          D       1.0 2012-07-18
# 208              315.00          D       1.0 2014-02-21
# 1242             499.00          D       1.0 2002-09-09
# 647             1038.00          D       1.0 2011-07-15
# 696              315.00          D       1.0 2012-01-04
# 657               58.71          D       1.0 2011-12-23
# 1187            1027.50          Q       6.0 2015-03-31
# 1127             499.00          D       1.0 2005-08-18
# 615              499.00          D       1.0 2005-08-18
# 850               58.97          D       1.0 2011-06-22
# 1077             499.00          D       1.0 2002-10-23
# 91               499.00          D       1.0 2006-07-03
# 156              776.79          D       1.0 2012-12-20
# 514              776.79          D       1.0 2012-12-20
# 924             3433.00          F       1.0 2011-02-12
# 869              138.00          D       1.0 1995-04-11
# 659             6000.00          F       1.0 2012-01-18
# 239              499.00          D       1.0 2012-04-11
# 1197             108.00          D       1.0 1996-05-30
# ...                 ...        ...       ...        ...
# 116              749.00          D       1.0 2014-11-24
# 656              138.00          D       1.0 1999-12-28
# 633              499.00          D       1.0 2006-06-08
# 173              138.00          D       1.0 1999-12-28
# 266              499.00          D       1.0 2007-06-21
# 167              115.00          D       1.0 2013-11-25
# 299               58.71          D       1.0 2012-04-12
# 75               499.00          D       1.0 1998-12-01
# 885              749.00          D       1.0 2014-11-24
# 79               138.00          D       1.0 2002-04-25
# 1176             499.00          D       1.0 2008-02-26
# 88               499.00          D       1.0 2002-11-13
# 1091             499.00          D       1.0 2002-09-23
# 1196             138.00          D       1.0 1995-05-16
# 977              749.00          D       1.0 2014-09-22
# 816              499.00          D       1.0 2011-11-30
# 477               58.71          D       1.0 2011-12-23
# 114                8.37          A       1.0 2016-10-19
# 865             3366.00          F       1.0 1999-03-10
# 467              138.00          D       1.0 2003-06-21
# 1085              58.97          D       1.0 2013-01-17
# 469              106.14          B       3.0 2012-10-26
# 399              120.00          D       1.0 2012-01-20
# 228              499.00          D       1.0 2004-05-12
# 950              138.00          D       1.0 2011-12-30
# 881             1038.00          D       1.0 2011-07-15
# 276              499.00          D       1.0 2012-04-26
# 586              499.00          D       1.0 2012-12-03
# 133              499.00          D       1.0 2006-01-06
# 699              138.00          D       1.0 2000-08-22
#
# [873 rows x 11 columns]

# %%
Master_test = MA_Data_Shuffle.copy()
for orignal_index in Master_training['original_index']:
    Master_test = Master_test[Master_test.original_index != orignal_index]

Master_test
# Out:
#       original_index State                Station Name (LEA)  \
# 7                558    MA                MILTON POLICE DEPT
# 11               695    MA           NEW BEDFORD POLICE DEPT
# 12               837    MA                REVERE POLICE DEPT
# 14              1097    MA             TOPSFIELD POLICE DEPT
# 15                57    MA        CENTRAL MA LAW ENFORCEMENT
# 16               629    MA                MILTON POLICE DEPT
# 18              1286    MA        WESTPORT POLICE DEPARTMENT
# 24               707    MA           NEW BEDFORD POLICE DEPT
# 28               985    MA              SOMERSET POLICE DEPT
# 32               271    MA                GROTON POLICE DEPT
# 35               573    MA                MILTON POLICE DEPT
# 41               845    MA                REVERE POLICE DEPT
# 45               105    MA              COHASSET POLICE DEPT
# 46               725    MA               NORFOLK POLICE DEPT
# 54               820    MA                REVERE POLICE DEPT
# 55              1047    MA            STURBRIDGE POLICE DEPT
# 58               270    MA                GROTON POLICE DEPT
# 59               430    MA             MANSFIELD POLICE DEPT
# 60               340    MA               IPSWICH POLICE DEPT
# 63               316    MA             HAVERHILL POLICE DEPT
# 64              1185    MA               WAREHAM POLICE DEPT
# 73               351    MA               IPSWICH POLICE DEPT
# 77               797    MA                QUINCY POLICE DEPT
# 87                63    MA              CHARLTON POLICE DEPT
# 89               791    MA                QUINCY POLICE DEPT
# 94               217    MA              FRANKLIN POLICE DEPT
# 96               172    MA               EVERETT POLICE DEPT
# 98               655    MA                MILTON POLICE DEPT
# 99               947    MA         SHIRLEY POLICE DEPARTMENT
# 103              818    MA                REVERE POLICE DEPT
# ...              ...   ...                               ...
# 1195             315    MA             HAVERHILL POLICE DEPT
# 1199            1300    MA        WESTPORT POLICE DEPARTMENT
# 1202             650    MA                MILTON POLICE DEPT
# 1203            1092    MA             TEMPLETON POLICE DEPT
# 1212             402    MA             LEXINGTON POLICE DEPT
# 1216              16    MA                AUBURN POLICE DEPT
# 1221             915    MA  SALEM STATE COLLEGE POLICE HI_ED
# 1222             249    MA            GLOUCESTER POLICE DEPT
# 1227             284    MA                HADLEY POLICE DEPT
# 1230             432    MA            MARBLEHEAD POLICE DEPT
# 1231             787    MA                QUINCY POLICE DEPT
# 1239             494    MA               MEDFORD POLICE DEPT
# 1240             305    MA               HARWICH POLICE DEPT
# 1243             614    MA                MILTON POLICE DEPT
# 1244             609    MA                MILTON POLICE DEPT
# 1245             240    MA            GLOUCESTER POLICE DEPT
# 1247             841    MA                REVERE POLICE DEPT
# 1250             104    MA              COHASSET POLICE DEPT
# 1259            1175    MA               WAREHAM POLICE DEPT
# 1267             197    MA            FRAMINGHAM POLICE DEPT
# 1268             950    MA              SOMERSET POLICE DEPT
# 1271             961    MA              SOMERSET POLICE DEPT
# 1272             899    MA              ROCKLAND POLICE DEPT
# 1278            1066    MA            SWAMPSCOTT POLICE DEPT
# 1279            1284    MA        WESTPORT POLICE DEPARTMENT
# 1283            1173    MA               WAREHAM POLICE DEPT
# 1293             442    MA            MARSHFIELD POLICE DEPT
# 1297             124    MA                DHS/ICE/HSI BOSTON
# 1302              66    MA         CHATHAM POLICE DEPARTMENT
# 1307             726    MA           NORTHBRIDGE POLICE DEPT
#
#                    NSN                             Item Name  Quantity    UI  \
# 7     1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 11    1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 12    1240-01-540-3763                 TELESCOPE SUBASSEMBLY        11  Each
# 14    1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 15    1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 16    1240-01-411-1265                          SIGHT,REFLEX         2  Each
# 18    5855-01-447-8992                  ILLUMINATOR,INFRARED         1  Each
# 24    1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 28    1005-00-999-1509               PIN,FIRING PIN RETAINER        20  Each
# 32    2320-01-371-9577                         TRUCK,UTILITY         1  Each
# 35    5855-01-468-4169                  ILLUMINATOR,INFRARED         1  Each
# 41    1005-00-726-5655          PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 45    1005-00-856-6885                 RIFLE,5.56 MILLIMETER         1  Each
# 46    2320-01-128-9551                         TRUCK,UTILITY         1  Each
# 54    1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 55    1005-01-128-9936                 RIFLE,5.56 MILLIMETER         1  Each
# 58    1005-00-856-6885                 RIFLE,5.56 MILLIMETER         1  Each
# 59    1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 60    5985-00-106-6130                               ANTENNA         4  Each
# 63    1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 64    5310-01-233-8625                       NUT,PLAIN,ROUND         8  Each
# 73    1240-01-411-1265                          SIGHT,REFLEX         1  Each
# 77    2320-01-346-9317                         TRUCK,UTILITY         1  Each
# 87    1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 89    1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 94    1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 96    2320-01-107-7155                         TRUCK,UTILITY         1  Each
# 98    5855-01-468-4169                  ILLUMINATOR,INFRARED         1  Each
# 99    1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 103   1005-00-726-5655          PISTOL,CALIBER .45,AUTOMATIC         1  Each
# ...                ...                                   ...       ...   ...
# 1195  1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 1199  2320-01-107-7155                         TRUCK,UTILITY         1  Each
# 1202  1240-01-492-5264                   SIGHT,HOLOGRAPHIC          25  Each
# 1203  1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 1212  1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 1216  1005-00-726-5655          PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 1221  1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 1222  2320-01-107-7156                         TRUCK,UTILITY         1  Each
# 1227  1005-00-856-6885                 RIFLE,5.56 MILLIMETER         1  Each
# 1230  1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 1231  1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 1239  1005-01-233-8529       BARREL AND FRONT SIGHT ASSEMBLY        45  Each
# 1240  1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 1243  5855-01-468-4169                  ILLUMINATOR,INFRARED         1  Each
# 1244  5855-01-468-4169                  ILLUMINATOR,INFRARED         1  Each
# 1245  8415-01-535-0064  COVERALLS,COMBAT VEHICLE CREWMEMBERS        10  Each
# 1247  6110-01-463-9260              CONTROL,REMOTE SWITCHING         2  Each
# 1250  1005-00-856-6885                 RIFLE,5.56 MILLIMETER         1  Each
# 1259  2320-01-107-7155                         TRUCK,UTILITY         1  Each
# 1267  1005-00-073-9421                 RIFLE,5.56 MILLIMETER         1  Each
# 1268  1005-01-184-4041                 BOLT,AUTOMATIC WEAPON        20  Each
# 1271  1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 1272  1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 1278  1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
# 1279  2320-01-107-7155                         TRUCK,UTILITY         1  Each
# 1283  5305-01-484-7075                SCREW,CAP,HEXAGON HEAD        10  Each
# 1293  2320-01-107-7155                         TRUCK,UTILITY         1  Each
# 1297  6510-01-541-8121                   BANDAGE,ABDOMINAL          99  Each
# 1302  2320-01-107-7153                         TRUCK,UTILITY         1  Each
# 1307  1005-00-589-1271                 RIFLE,7.62 MILLIMETER         1  Each
#
#       Acquisition Value DEMIL Code  DEMIL IC  Ship Date
# 7                138.00          D       1.0 2011-12-29
# 11               499.00          D       1.0 2012-01-17
# 12               110.06          D       1.0 2011-10-07
# 14               499.00          D       1.0 2002-09-09
# 15               138.00          D       1.0 2006-09-07
# 16               315.00          D       1.0 2010-08-19
# 18              1038.00          D       1.0 2011-07-15
# 24               499.00          D       1.0 2012-01-17
# 28                 0.64          B       3.0 2011-11-09
# 32             47023.00          Q       6.0 2012-06-15
# 35               776.79          D       1.0 2012-12-20
# 41                58.71          D       1.0 2011-12-23
# 45               120.00          D       1.0 2011-10-18
# 46             50458.00          C       1.0 2012-06-13
# 54               499.00          D       1.0 2007-06-25
# 55               749.00          D       1.0 2014-09-22
# 58               120.00          D       1.0 2011-10-19
# 59               499.00          D       1.0 1998-12-01
# 60               861.80          D       1.0 2014-03-11
# 63               138.00          D       1.0 2000-04-11
# 64                 4.02          B       3.0 2013-01-14
# 73               315.00          D       1.0 2011-11-16
# 77             58939.00          C       1.0 2012-04-09
# 87               499.00          D       1.0 2006-07-03
# 89               499.00          D       1.0 2005-12-05
# 94               138.00          D       1.0 2002-03-19
# 96             41061.00          Q       6.0 2011-12-27
# 98               776.79          D       1.0 2012-12-20
# 99               138.00          D       1.0 1999-12-28
# 103               58.71          D       1.0 2011-12-23
# ...                 ...        ...       ...        ...
# 1195             138.00          D       1.0 2000-04-11
# 1199           41061.00          Q       6.0 2011-05-18
# 1202             506.80          D       1.0 2015-05-27
# 1203             499.00          D       1.0 2007-06-21
# 1212             499.00          D       1.0 2012-12-03
# 1216              58.71          D       1.0 2012-04-12
# 1221             138.00          D       1.0 2008-11-12
# 1222           43376.00          Q       6.0 2012-06-26
# 1227             120.00          D       1.0 2011-10-19
# 1230             499.00          D       1.0 2002-08-20
# 1231             499.00          D       1.0 2005-12-05
# 1239             115.00          D       1.0 2014-11-04
# 1240             499.00          D       1.0 2004-05-03
# 1243             776.79          D       1.0 2012-07-18
# 1244             776.79          D       1.0 2012-07-18
# 1245             256.98          E       7.0 2012-01-18
# 1247             101.00          B       3.0 2011-04-27
# 1250             120.00          D       1.0 2011-10-18
# 1259           41061.00          Q       6.0 2012-10-26
# 1267             499.00          D       1.0 1998-12-21
# 1268             217.21          D       1.0 2011-09-24
# 1271             138.00          D       1.0 2003-06-21
# 1272             138.00          D       1.0 2000-07-18
# 1278             138.00          D       1.0 1999-12-28
# 1279           41061.00          Q       6.0 2011-09-16
# 1283               2.90          B       3.0 2013-02-19
# 1293           41061.00          Q       6.0 2011-12-15
# 1297              13.42          A       1.0 2017-03-22
# 1302           63894.00          C       1.0 2010-09-13
# 1307             138.00          D       1.0 2003-06-25
#
# [436 rows x 11 columns]

# %%
testset_1 = Master_test.sample(round(len(MA_Data_Shuffle)*1/12), replace=False)

# %%
testset_4 = Master_test.copy()
for orignal_index in testset_1['original_index']:
    testset_4 = testset_4[testset_4.original_index != orignal_index]

# %%
testset_2 = testset_4.sample(round(len(MA_Data_Shuffle)*1/12), replace=False)

# %%
for orignal_index in testset_2['original_index']:
    testset_4 = testset_4[testset_4.original_index != orignal_index]

# %%
testset_3 = testset_4.sample(round(len(MA_Data_Shuffle)*1/12), replace=False)

# %%
for orignal_index in testset_3['original_index']:
    testset_4 = testset_4[testset_4.original_index != orignal_index]

# %%
testset_1
# Out:
#       original_index State            Station Name (LEA)               NSN  \
# 1283            1173    MA           WAREHAM POLICE DEPT  5305-01-484-7075
# 971              487    MA           MEDFORD POLICE DEPT  1005-00-073-9421
# 575              962    MA          SOMERSET POLICE DEPT  5855-01-432-0524
# 290              282    MA            HADLEY POLICE DEPT  1005-00-589-1271
# 607              486    MA           MEDFORD POLICE DEPT  1005-00-073-9421
# 1011             381    MA          LAWRENCE POLICE DEPT  1005-00-856-6885
# 894              118    MA         DARTMOUTH POLICE DEPT  2320-01-380-8604
# 326              455    MA           MAYNARD POLICE DEPT  1005-00-073-9421
# 1141             107    MA        CUMMINGTON POLICE DEPT  7021-DS-LAP-TOP2
# 764               59    MA    CENTRAL MA LAW ENFORCEMENT  1005-00-589-1271
# 144              806    MA               REHOBOTH POLICE  1005-00-073-9421
# 754              721    MA      NEW BRANTREE POLICE DEPT  2320-01-107-7155
# 1052            1235    MA         WELLESLEY POLICE DEPT  6545-01-530-0929
# 1108            1270    MA   WESTFIELD POLICE DEPARTMENT  1005-00-073-9421
# 732              713    MA       NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 767              835    MA            REVERE POLICE DEPT  4240-01-092-3172
# 136              222    MA          FREETOWN POLICE DEPT  2320-01-128-9551
# 1156             307    MA           HARWICH POLICE DEPT  1005-00-589-1271
# 1152              26    MA            AUBURN POLICE DEPT  1005-00-073-9421
# 213              982    MA          SOMERSET POLICE DEPT  8470-01-476-5648
# 54               820    MA            REVERE POLICE DEPT  1005-00-073-9421
# 379              378    MA          LAWRENCE POLICE DEPT  1005-00-856-6885
# 655             1070    MA           SWANSEA POLICE DEPT  1005-00-073-9421
# 1109            1253    MA  WEST SPRINGFIELD POLICE DEPT  1005-00-589-1271
# 346             1272    MA   WESTFIELD POLICE DEPARTMENT  1005-00-073-9421
# 768             1240    MA         WELLFLEET POLICE DEPT  1005-00-589-1271
# 450              664    MA       NEW BEDFORD POLICE DEPT  2320-01-107-7155
# 1033            1256    MA   WESTFIELD POLICE DEPARTMENT  1005-00-073-9421
# 536             1098    MA         TOPSFIELD POLICE DEPT  1005-00-589-1271
# 1093             780    MA  PLYMOUTH COUNTY SHERIFF DEPT  2540-01-408-7049
# ...              ...   ...                           ...               ...
# 1028              96    MA          COHASSET POLICE DEPT  1005-00-856-6885
# 235              735    MA            NORTON POLICE DEPT  1005-00-073-9421
# 500              588    MA            MILTON POLICE DEPT  5855-01-468-4169
# 126              478    MA           MEDFORD POLICE DEPT  1005-00-073-9421
# 128              739    MA            NORTON POLICE DEPT  1005-00-073-9421
# 181              400    MA         LEXINGTON POLICE DEPT  1005-00-073-9421
# 960              932    MA          SCITUATE POLICE DEPT  5180-00-163-6638
# 1097              81    MA          CHICOPEE POLICE DEPT  1005-00-589-1271
# 257              988    MA          SOMERSET POLICE DEPT  1005-00-921-5004
# 423             1196    MA           WAREHAM POLICE DEPT  1005-01-233-8638
# 98               655    MA            MILTON POLICE DEPT  5855-01-468-4169
# 1195             315    MA         HAVERHILL POLICE DEPT  1005-00-589-1271
# 351              349    MA           IPSWICH POLICE DEPT  1005-00-999-1871
# 819               11    MA            AUBURN POLICE DEPT  1005-00-073-9421
# 582             1035    MA       SOUTHBRIDGE POLICE DEPT  1005-00-073-9421
# 915              989    MA        SOMERVILLE POLICE DEPT  1005-00-856-6885
# 142             1171    MA           WAREHAM POLICE DEPT  1005-01-453-1633
# 28               985    MA          SOMERSET POLICE DEPT  1005-00-999-1509
# 1222             249    MA        GLOUCESTER POLICE DEPT  2320-01-107-7156
# 1162             238    MA        GLOUCESTER POLICE DEPT  8415-01-535-0038
# 1267             197    MA        FRAMINGHAM POLICE DEPT  1005-00-073-9421
# 1279            1284    MA    WESTPORT POLICE DEPARTMENT  2320-01-107-7155
# 714              903    MA          ROCKLAND POLICE DEPT  1005-00-073-9421
# 1227             284    MA            HADLEY POLICE DEPT  1005-00-856-6885
# 1278            1066    MA        SWAMPSCOTT POLICE DEPT  1005-00-589-1271
# 12               837    MA            REVERE POLICE DEPT  1240-01-540-3763
# 628              891    MA            REVERE POLICE DEPT  1005-00-726-5655
# 645              720    MA      NEW BRANTREE POLICE DEPT  1240-00-930-3833
# 45               105    MA          COHASSET POLICE DEPT  1005-00-856-6885
# 194               22    MA            AUBURN POLICE DEPT  1005-00-589-1271
#
#                                  Item Name  Quantity    UI  Acquisition Value  \
# 1283                SCREW,CAP,HEXAGON HEAD        10  Each               2.90
# 971                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 575                    VIEWER,NIGHT VISION         1  Each            3607.00
# 290                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 607                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1011                 RIFLE,5.56 MILLIMETER         1  Each             120.00
# 894                          TRUCK,UTILITY         1  Each           81226.00
# 326                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1141                       LAPTOP COMPUTER         4  Each            1125.00
# 764                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 144                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 754                          TRUCK,UTILITY         1  Each           41061.00
# 1052               FIRST AID KIT,UNIVERSAL        30   Kit              99.25
# 1108                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# 732                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 767         HARNESS ASSEMBLY,TROOP TYPE II        12  Each            2024.64
# 136                          TRUCK,UTILITY         1  Each           50458.00
# 1156                 RIFLE,7.62 MILLIMETER         1  Each             138.00
# 1152                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# 213          PAD SET,SUSPENSION SYSTEM,ACH         6   Set              63.66
# 54                   RIFLE,5.56 MILLIMETER         1  Each             499.00
# 379                  RIFLE,5.56 MILLIMETER         1  Each             120.00
# 655                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1109                 RIFLE,7.62 MILLIMETER         1  Each             138.00
# 346                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 768                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 450                          TRUCK,UTILITY         1  Each           41061.00
# 1033                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# 536                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 1093              PARTS KIT,SEAT,VEHICULAR         1  Each             750.00
# ...                                    ...       ...   ...                ...
# 1028                 RIFLE,5.56 MILLIMETER         1  Each             120.00
# 235                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 500                   ILLUMINATOR,INFRARED         1  Each             776.79
# 126                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 128                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 181                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 960          TOOL KIT,AIRCRAFT MAINTENANCE         3  Each             307.50
# 1097                 RIFLE,7.62 MILLIMETER         1  Each             138.00
# 257                     MAGAZINE,CARTRIDGE       100  Each              12.30
# 423               LEVER,RELEASE,SMALL ARMS        15  Each               2.21
# 98                    ILLUMINATOR,INFRARED         1  Each             776.79
# 1195                 RIFLE,7.62 MILLIMETER         1  Each             138.00
# 351                     STOCK,GUN,SHOULDER         2  Each             707.36
# 819                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 582                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 915                  RIFLE,5.56 MILLIMETER         1  Each             120.00
# 142                    HANDGUARD,LOWER             3  Each              26.92
# 28                 PIN,FIRING PIN RETAINER        20  Each               0.64
# 1222                         TRUCK,UTILITY         1  Each           43376.00
# 1162  COVERALLS,COMBAT VEHICLE CREWMEMBERS         2  Each             256.98
# 1267                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1279                         TRUCK,UTILITY         1  Each           41061.00
# 714                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1227                 RIFLE,5.56 MILLIMETER         1  Each             120.00
# 1278                 RIFLE,7.62 MILLIMETER         1  Each             138.00
# 12                   TELESCOPE SUBASSEMBLY        11  Each             110.06
# 628           PISTOL,CALIBER .45,AUTOMATIC         1  Each              58.71
# 645                              BINOCULAR         1  Each             278.05
# 45                   RIFLE,5.56 MILLIMETER         1  Each             120.00
# 194                  RIFLE,7.62 MILLIMETER         1  Each             138.00
#
#      DEMIL Code  DEMIL IC  Ship Date
# 1283          B       3.0 2013-02-19
# 971           D       1.0 2006-02-16
# 575           F       1.0 2012-01-05
# 290           D       1.0 1995-02-02
# 607           D       1.0 2006-02-21
# 1011          D       1.0 2011-07-21
# 894           C       1.0 2011-06-10
# 326           D       1.0 2013-02-27
# 1141          Q       NaN 2012-12-17
# 764           D       1.0 2006-09-07
# 144           D       1.0 2006-06-08
# 754           Q       6.0 2012-12-05
# 1052          A       1.0 2017-05-12
# 1108          D       1.0 2004-05-12
# 732           D       1.0 2012-01-17
# 767           B       3.0 2012-06-09
# 136           C       1.0 2011-12-19
# 1156          D       1.0 1996-06-26
# 1152          D       1.0 2012-04-11
# 213           B       3.0 2011-11-09
# 54            D       1.0 2007-06-25
# 379           D       1.0 2011-07-21
# 655           D       1.0 2006-06-10
# 1109          D       1.0 1996-09-10
# 346           D       1.0 2004-05-12
# 768           D       1.0 2000-08-02
# 450           Q       6.0 2012-06-08
# 1033          D       1.0 2004-05-12
# 536           D       1.0 1999-04-07
# 1093          Q       6.0 2014-02-07
# ...         ...       ...        ...
# 1028          D       1.0 2011-10-18
# 235           D       1.0 2012-03-20
# 500           D       1.0 2012-07-18
# 126           D       1.0 2006-02-22
# 128           D       1.0 2012-04-17
# 181           D       1.0 2012-12-03
# 960           B       3.0 2014-07-16
# 1097          D       1.0 1995-02-02
# 257           D       1.0 2011-12-31
# 423           D       1.0 2013-01-29
# 98            D       1.0 2012-12-20
# 1195          D       1.0 2000-04-11
# 351           B       3.0 2013-05-20
# 819           D       1.0 2012-04-11
# 582           D       1.0 2011-11-30
# 915           D       1.0 2011-09-26
# 142           B       3.0 2013-07-03
# 28            B       3.0 2011-11-09
# 1222          Q       6.0 2012-06-26
# 1162          E       1.0 2012-01-06
# 1267          D       1.0 1998-12-21
# 1279          Q       6.0 2011-09-16
# 714           D       1.0 2002-09-09
# 1227          D       1.0 2011-10-19
# 1278          D       1.0 1999-12-28
# 12            D       1.0 2011-10-07
# 628           D       1.0 2011-12-23
# 645           D       1.0 2012-07-22
# 45            D       1.0 2011-10-18
# 194           D       1.0 2012-04-12
#
# [109 rows x 11 columns]

# %%
testset_2
# Out:
#       original_index State          Station Name (LEA)               NSN  \
# 249              468    MA         MEDFORD POLICE DEPT  1005-00-179-0300
# 534              870    MA          REVERE POLICE DEPT  1005-00-726-5655
# 619              269    MA          GROTON POLICE DEPT  1005-00-856-6885
# 1138              77    MA         CHELSEA POLICE DEPT  1005-01-128-9936
# 739              224    MA      GLOUCESTER POLICE DEPT  1240-01-411-1265
# 649              338    MA         IPSWICH POLICE DEPT  1005-00-073-9421
# 683             1157    MA         WAREHAM POLICE DEPT  1005-00-589-1271
# 1059             239    MA      GLOUCESTER POLICE DEPT  8415-01-535-0064
# 94               217    MA        FRANKLIN POLICE DEPT  1005-00-589-1271
# 374                4    MA           ACTON POLICE DEPT  1005-00-589-1271
# 592                6    MA          AUBURN POLICE DEPT  1005-00-073-9421
# 444             1231    MA       WELLESLEY POLICE DEPT  6545-01-527-1078
# 1095             660    MA          MONSON POLICE DEPT  1005-00-073-9421
# 342             1068    MA         SWANSEA POLICE DEPT  2320-01-107-7155
# 923             1159    MA         WAREHAM POLICE DEPT  5305-01-484-7075
# 204             1165    MA         WAREHAM POLICE DEPT  5360-00-992-7308
# 115              409    MA          LEYDEN POLICE DEPT  1240-01-411-1265
# 620              480    MA         MEDFORD POLICE DEPT  1005-00-073-9421
# 810              183    MA       FAIRHAVEN POLICE DEPT  1005-00-073-9421
# 1006            1055    MA      STURBRIDGE POLICE DEPT  1005-01-128-9936
# 64              1185    MA         WAREHAM POLICE DEPT  5310-01-233-8625
# 807              165    MA         EVERETT POLICE DEPT  1005-00-589-1271
# 1150             853    MA          REVERE POLICE DEPT  1005-00-726-5655
# 73               351    MA         IPSWICH POLICE DEPT  1240-01-411-1265
# 195              459    MA         MAYNARD POLICE DEPT  1005-00-073-9421
# 863              495    MA          MEDWAY POLICE DEPT  1005-00-589-1271
# 496              532    MA         METHUEN POLICE DEPT  1005-00-073-9421
# 1111             983    MA        SOMERSET POLICE DEPT  1005-00-589-1271
# 247              927    MA        SCITUATE POLICE DEPT  5120-00-471-3316
# 113              135    MA         DIGHTON POLICE DEPT  4940-01-333-8470
# ...              ...   ...                         ...               ...
# 604              938    MA        SCITUATE POLICE DEPT  6150-01-561-1693
# 1128             923    MA        SCITUATE POLICE DEPT  2320-01-371-9584
# 77               797    MA          QUINCY POLICE DEPT  2320-01-346-9317
# 1027             877    MA          REVERE POLICE DEPT  1005-00-073-9421
# 1129            1301    MA  WESTPORT POLICE DEPARTMENT  1005-00-073-9421
# 654              242    MA      GLOUCESTER POLICE DEPT  5855-01-228-0939
# 369             1026    MA     SOUTHBRIDGE POLICE DEPT  1005-00-073-9421
# 822             1114    MA    TYNGSBOROUGH POLICE DEPT  1005-01-128-9936
# 707              943    MA        SCITUATE POLICE DEPT  5120-00-468-1311
# 529              600    MA          MILTON POLICE DEPT  5855-01-468-4169
# 535              140    MA             DOJ/USMS BOSTON  8465-01-515-8615
# 967             1177    MA         WAREHAM POLICE DEPT  1005-00-073-9421
# 155              710    MA     NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 613              370    MA        LAWRENCE POLICE DEPT  1005-00-073-9421
# 742              643    MA          MILTON POLICE DEPT  1005-00-589-1271
# 830              218    MA        FRANKLIN POLICE DEPT  1005-00-589-1271
# 1101             734    MA          NORTON POLICE DEPT  1005-00-589-1271
# 1212             402    MA       LEXINGTON POLICE DEPT  1005-00-073-9421
# 1078              99    MA        COHASSET POLICE DEPT  1005-00-589-1271
# 267              410    MA          LEYDEN POLICE DEPT  3805-01-268-8645
# 1169             212    MA        FRANKLIN POLICE DEPT  1005-00-589-1271
# 7                558    MA          MILTON POLICE DEPT  1005-00-589-1271
# 1143              28    MA          AUBURN POLICE DEPT  1240-01-411-1265
# 147              514    MA         METHUEN POLICE DEPT  1005-00-073-9421
# 794              151    MA             DOJ/USMS BOSTON  8465-01-532-2393
# 556              394    MA       LEXINGTON POLICE DEPT  1005-00-073-9421
# 340              880    MA          REVERE POLICE DEPT  1005-00-073-9421
# 1302              66    MA   CHATHAM POLICE DEPARTMENT  2320-01-107-7153
# 318             1209    MA          WARREN POLICE DEPT  1005-00-589-1271
# 802              969    MA        SOMERSET POLICE DEPT  5855-01-488-6563
#
#                                      Item Name  Quantity    UI  \
# 249                      RIFLE,7.62 MILLIMETER         1  Each
# 534               PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 619                      RIFLE,5.56 MILLIMETER         1  Each
# 1138                     RIFLE,5.56 MILLIMETER         1  Each
# 739                               SIGHT,REFLEX        20  Each
# 649                      RIFLE,5.56 MILLIMETER         1  Each
# 683                      RIFLE,7.62 MILLIMETER         1  Each
# 1059      COVERALLS,COMBAT VEHICLE CREWMEMBERS         2  Each
# 94                       RIFLE,7.62 MILLIMETER         1  Each
# 374                      RIFLE,7.62 MILLIMETER         1  Each
# 592                      RIFLE,5.56 MILLIMETER         1  Each
# 444   CASE,MEDICAL MODULAR PRIMARY CARE ORGANI         1  Each
# 1095                     RIFLE,5.56 MILLIMETER         1  Each
# 342                              TRUCK,UTILITY         1  Each
# 923                     SCREW,CAP,HEXAGON HEAD        10  Each
# 204                     SPRING,HELICAL,TORSION        20  Each
# 115                               SIGHT,REFLEX         4  Each
# 620                      RIFLE,5.56 MILLIMETER         1  Each
# 810                      RIFLE,5.56 MILLIMETER         1  Each
# 1006                     RIFLE,5.56 MILLIMETER         1  Each
# 64                             NUT,PLAIN,ROUND         8  Each
# 807                      RIFLE,7.62 MILLIMETER         1  Each
# 1150              PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 73                                SIGHT,REFLEX         1  Each
# 195                      RIFLE,5.56 MILLIMETER         1  Each
# 863                      RIFLE,7.62 MILLIMETER         1  Each
# 496                      RIFLE,5.56 MILLIMETER         1  Each
# 1111                     RIFLE,7.62 MILLIMETER         1  Each
# 247                    PUSHER,BEARING ASSEMBLY         1  Each
# 113         SHOP EQUIPMENT,CONTACT MAINTENANCE         1  Each
# ...                                        ...       ...   ...
# 604                       LEAD,STORAGE BATTERY         6  Each
# 1128                             TRUCK,UTILITY         1  Each
# 77                               TRUCK,UTILITY         1  Each
# 1027                     RIFLE,5.56 MILLIMETER         1  Each
# 1129                     RIFLE,5.56 MILLIMETER         1  Each
# 654                        NIGHT VISION GOGGLE         1  Each
# 369                      RIFLE,5.56 MILLIMETER         1  Each
# 822                      RIFLE,5.56 MILLIMETER         1  Each
# 707                 REMOVAL TOOL,DISK AIR SEAL         1  Each
# 529                       ILLUMINATOR,INFRARED         1  Each
# 535                                 FIELD PACK        30  Each
# 967                      RIFLE,5.56 MILLIMETER         1  Each
# 155                      RIFLE,5.56 MILLIMETER         1  Each
# 613                      RIFLE,5.56 MILLIMETER         1  Each
# 742                      RIFLE,7.62 MILLIMETER         1  Each
# 830                      RIFLE,7.62 MILLIMETER         1  Each
# 1101                     RIFLE,7.62 MILLIMETER         1  Each
# 1212                     RIFLE,5.56 MILLIMETER         1  Each
# 1078                     RIFLE,7.62 MILLIMETER         1  Each
# 267                          LOADER,SCOOP TYPE         1  Each
# 1169                     RIFLE,7.62 MILLIMETER         1  Each
# 7                        RIFLE,7.62 MILLIMETER         1  Each
# 1143                              SIGHT,REFLEX        16  Each
# 147                      RIFLE,5.56 MILLIMETER         1  Each
# 794                        POCKET,PYROTECHNIC        100  Each
# 556                      RIFLE,5.56 MILLIMETER         1  Each
# 340                      RIFLE,5.56 MILLIMETER         1  Each
# 1302                             TRUCK,UTILITY         1  Each
# 318                      RIFLE,7.62 MILLIMETER         1  Each
# 802                       ILLUMINATOR,INFRARED         1  Each
#
#       Acquisition Value DEMIL Code  DEMIL IC  Ship Date
# 249             1278.00          D       1.0 1996-06-04
# 534               58.71          D       1.0 2011-12-23
# 619              120.00          D       1.0 2011-10-19
# 1138             749.00          D       1.0 2014-09-22
# 739              315.00          D       1.0 2012-03-14
# 649              499.00          D       1.0 2007-06-21
# 683              138.00          D       1.0 2005-12-27
# 1059             256.98          E       7.0 2012-01-06
# 94               138.00          D       1.0 2002-03-19
# 374              138.00          D       1.0 2000-09-06
# 592              499.00          D       1.0 2012-04-11
# 444              882.32          A       1.0 2016-10-21
# 1095             499.00          D       1.0 1999-06-14
# 342            41061.00          Q       6.0 2013-01-03
# 923                2.90          B       3.0 2013-02-19
# 204                0.42          B       3.0 2013-04-24
# 115              315.00          D       1.0 2015-03-19
# 620              499.00          D       1.0 2006-02-16
# 810              499.00          D       1.0 2008-02-26
# 1006             749.00          D       1.0 2014-09-22
# 64                 4.02          B       3.0 2013-01-14
# 807              138.00          D       1.0 2002-04-25
# 1150              58.71          D       1.0 2011-12-23
# 73               315.00          D       1.0 2011-11-16
# 195              499.00          D       1.0 2013-02-27
# 863              138.00          D       1.0 2004-04-12
# 496              499.00          D       1.0 2008-07-29
# 1111             138.00          D       1.0 2003-06-21
# 247             2195.93          B       3.0 2012-07-31
# 113            46793.00          A       1.0 2012-07-03
# ...                 ...        ...       ...        ...
# 604               29.01          B       3.0 2015-03-31
# 1128           62627.00          C       1.0 2015-04-02
# 77             58939.00          C       1.0 2012-04-09
# 1027             499.00          D       1.0 2007-06-26
# 1129             499.00          D       1.0 2002-10-23
# 654             6000.00          F       1.0 2012-01-18
# 369              499.00          D       1.0 2011-11-30
# 822              749.00          D       1.0 2014-12-01
# 707              457.62          B       3.0 2012-07-31
# 529              776.79          D       1.0 2012-07-18
# 535              548.59          A       1.0 2013-07-17
# 967              499.00          D       1.0 2005-12-28
# 155              499.00          D       1.0 2012-01-17
# 613              499.00          D       1.0 2012-04-26
# 742              138.00          D       1.0 2011-12-30
# 830              138.00          D       1.0 2002-03-19
# 1101             138.00          D       1.0 2011-12-29
# 1212             499.00          D       1.0 2012-12-03
# 1078             138.00          D       1.0 2011-10-18
# 267                0.00          A       NaN 2017-01-30
# 1169             138.00          D       1.0 2002-03-19
# 7                138.00          D       1.0 2011-12-29
# 1143             315.00          D       1.0 2015-10-21
# 147              499.00          D       1.0 2008-07-29
# 794                6.12          A       1.0 2013-06-07
# 556              499.00          D       1.0 2012-12-03
# 340              499.00          D       1.0 2007-06-26
# 1302           63894.00          C       1.0 2010-09-13
# 318              138.00          D       1.0 2000-08-22
# 802             1794.00          D       1.0 2011-06-06
#
# [109 rows x 11 columns]

# %%
testset_3
# Out:
#       original_index State            Station Name (LEA)               NSN  \
# 625              528    MA           METHUEN POLICE DEPT  1005-00-589-1271
# 1144            1250    MA  WEST SPRINGFIELD POLICE DEPT  1005-00-179-0300
# 1245             240    MA        GLOUCESTER POLICE DEPT  8415-01-535-0064
# 256              385    MA          LAWRENCE POLICE DEPT  1005-00-073-9421
# 15                57    MA    CENTRAL MA LAW ENFORCEMENT  1005-00-589-1271
# 1163             353    MA           IPSWICH POLICE DEPT  1240-01-411-1265
# 182              254    MA           GRAFTON POLICE DEPT  1005-00-073-9421
# 227              872    MA            REVERE POLICE DEPT  1005-00-073-9421
# 720              993    MA        SOMERVILLE POLICE DEPT  1005-00-856-6885
# 140               73    MA           CHELSEA POLICE DEPT  1005-01-128-9936
# 976              352    MA           IPSWICH POLICE DEPT  1240-01-411-1265
# 11               695    MA       NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 826               30    MA            AUBURN POLICE DEPT  1005-00-073-9421
# 180             1277    MA    WESTPORT POLICE DEPARTMENT  6665-01-506-6219
# 951              342    MA           IPSWICH POLICE DEPT  7830-DS-RVC-AMPR
# 618              541    MA        MIDDLEBORO POLICE DEPT  1005-00-073-9421
# 1070            1262    MA   WESTFIELD POLICE DEPARTMENT  1005-00-073-9421
# 1148             764    MA           ORLEANS POLICE DEPT  1005-00-589-1271
# 229              510    MA           METHUEN POLICE DEPT  1005-00-073-9421
# 769              675    MA       NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 624             1230    MA         WELLESLEY POLICE DEPT  8150-01-483-9125
# 1149            1037    MA       SOUTHBRIDGE POLICE DEPT  2320-01-346-9317
# 107              537    MA           METHUEN POLICE DEPT  1005-00-073-9421
# 1164            1094    MA           TOLLAND POLICE DEPT  2320-01-107-7156
# 520              722    MA      NEW BRANTREE POLICE DEPT  2320-01-107-7155
# 987             1254    MA  WEST SPRINGFIELD POLICE DEPT  1005-00-589-1271
# 121              268    MA            GROTON POLICE DEPT  1005-00-856-6885
# 87                63    MA          CHARLTON POLICE DEPT  1005-00-073-9421
# 665             1123    MA      TYNGSBOROUGH POLICE DEPT  2320-01-346-9317
# 1114            1274    MA    WESTPORT POLICE DEPARTMENT  1005-00-073-9421
# ...              ...   ...                           ...               ...
# 984             1202    MA           WAREHAM POLICE DEPT  5360-01-233-8617
# 327             1251    MA  WEST SPRINGFIELD POLICE DEPT  1005-00-589-1271
# 1044             719    MA      NEW BRANTREE POLICE DEPT  2320-01-128-9551
# 1230             432    MA        MARBLEHEAD POLICE DEPT  1005-00-073-9421
# 32               271    MA            GROTON POLICE DEPT  2320-01-371-9577
# 436             1170    MA           WAREHAM POLICE DEPT  1005-01-453-4227
# 947              517    MA           METHUEN POLICE DEPT  1005-00-589-1271
# 1154             437    MA        MARBLEHEAD POLICE DEPT  1005-00-073-9421
# 710              309    MA           HARWICH POLICE DEPT  1005-00-073-9421
# 570              733    MA            NORTON POLICE DEPT  1005-00-589-1271
# 460             1295    MA    WESTPORT POLICE DEPARTMENT  5855-01-447-8992
# 627              369    MA          LAWRENCE POLICE DEPT  1005-00-073-9421
# 862                8    MA            AUBURN POLICE DEPT  1005-00-073-9421
# 1066             213    MA          FRANKLIN POLICE DEPT  1005-00-589-1271
# 1175             164    MA           EVERETT POLICE DEPT  1005-00-856-6885
# 1053            1162    MA           WAREHAM POLICE DEPT  2510-01-254-1501
# 55              1047    MA        STURBRIDGE POLICE DEPT  1005-01-128-9936
# 526              114    MA            DALTON POLICE DEPT  1005-00-073-9421
# 730              550    MA           MILFORD POLICE DEPT  1005-00-589-1271
# 1250             104    MA          COHASSET POLICE DEPT  1005-00-856-6885
# 860              674    MA       NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 509              509    MA           METHUEN POLICE DEPT  1005-00-073-9421
# 821              274    MA         GROVELAND POLICE DEPT  1005-00-856-6885
# 804              389    MA        LEOMINSTER POLICE DEPT  1005-00-073-9421
# 210              998    MA        SOMERVILLE POLICE DEPT  1005-00-856-6885
# 1135             127    MA           DIGHTON POLICE DEPT  8340-01-185-2628
# 1153              87    MA           CLINTON POLICE DEPT  1005-00-073-9421
# 772              847    MA            REVERE POLICE DEPT  1005-00-073-9421
# 517              444    MA        MARSHFIELD POLICE DEPT  1005-00-073-9421
# 1272             899    MA          ROCKLAND POLICE DEPT  1005-00-589-1271
#
#                                  Item Name  Quantity    UI  Acquisition Value  \
# 625                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 1144                 RIFLE,7.62 MILLIMETER         1  Each            1278.00
# 1245  COVERALLS,COMBAT VEHICLE CREWMEMBERS        10  Each             256.98
# 256                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 15                   RIFLE,7.62 MILLIMETER         1  Each             138.00
# 1163                          SIGHT,REFLEX         1  Each             315.00
# 182                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 227                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 720                  RIFLE,5.56 MILLIMETER         1  Each             120.00
# 140                  RIFLE,5.56 MILLIMETER         1  Each             749.00
# 976                           SIGHT,REFLEX         1  Each             315.00
# 11                   RIFLE,5.56 MILLIMETER         1  Each             499.00
# 826                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 180                     DETECTING SET,MINE         3  Each            5657.00
# 951           RECREATIONAL CAMPER, TRAILER         1  Each               0.00
# 618                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1070                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1148                 RIFLE,7.62 MILLIMETER         1  Each             138.00
# 229                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 769                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 624              CONTAINER,FREIGHT,UTILITY         1  Each            6694.87
# 1149                         TRUCK,UTILITY         1  Each           58939.00
# 107                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1164                         TRUCK,UTILITY         1  Each           43376.00
# 520                          TRUCK,UTILITY         1  Each           41061.00
# 987                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 121                  RIFLE,5.56 MILLIMETER         1  Each             120.00
# 87                   RIFLE,5.56 MILLIMETER         1  Each             499.00
# 665                          TRUCK,UTILITY         1  Each           58939.00
# 1114                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# ...                                    ...       ...   ...                ...
# 984             SPRING,HELICAL,COMPRESSION         5  Each               1.49
# 327                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 1044                         TRUCK,UTILITY         1  Each           50458.00
# 1230                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# 32                           TRUCK,UTILITY         1  Each           47023.00
# 436                    HANDGUARD,UPPER             1  Each              60.46
# 947                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 1154                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# 710                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 570                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 460                   ILLUMINATOR,INFRARED         1  Each            1038.00
# 627                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 862                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1066                 RIFLE,7.62 MILLIMETER         1  Each             138.00
# 1175                 RIFLE,5.56 MILLIMETER         1  Each             120.00
# 1053                        DOOR,VEHICULAR         1  Each             652.61
# 55                   RIFLE,5.56 MILLIMETER         1  Each             749.00
# 526                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 730                  RIFLE,7.62 MILLIMETER         1  Each             138.00
# 1250                 RIFLE,5.56 MILLIMETER         1  Each             120.00
# 860                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 509                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 821                  RIFLE,5.56 MILLIMETER         1  Each             120.00
# 804                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 210                  RIFLE,5.56 MILLIMETER         1  Each             120.00
# 1135                                  TENT         1  Each           10304.87
# 1153                 RIFLE,5.56 MILLIMETER         1  Each             499.00
# 772                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 517                  RIFLE,5.56 MILLIMETER         1  Each             499.00
# 1272                 RIFLE,7.62 MILLIMETER         1  Each             138.00
#
#      DEMIL Code  DEMIL IC  Ship Date
# 625           D       1.0 1999-12-27
# 1144          D       1.0 1997-01-21
# 1245          E       7.0 2012-01-18
# 256           D       1.0 2012-04-26
# 15            D       1.0 2006-09-07
# 1163          D       1.0 2012-01-04
# 182           D       1.0 2002-11-13
# 227           D       1.0 2007-06-26
# 720           D       1.0 2011-09-26
# 140           D       1.0 2014-09-22
# 976           D       1.0 2012-01-04
# 11            D       1.0 2012-01-17
# 826           D       1.0 2012-04-11
# 180           D       1.0 2011-06-28
# 951           A       NaN 2016-08-24
# 618           D       1.0 2005-01-05
# 1070          D       1.0 2004-05-12
# 1148          D       1.0 2002-03-19
# 229           D       1.0 2008-07-29
# 769           D       1.0 2012-01-17
# 624           A       1.0 2016-11-16
# 1149          C       1.0 2013-09-27
# 107           D       1.0 2008-07-29
# 1164          Q       6.0 2014-01-21
# 520           Q       6.0 2012-12-05
# 987           D       1.0 1996-09-10
# 121           D       1.0 2011-10-19
# 87            D       1.0 2006-07-03
# 665           C       1.0 2012-07-13
# 1114          D       1.0 2002-10-23
# ...         ...       ...        ...
# 984           B       3.0 2013-10-24
# 327           D       1.0 1996-09-10
# 1044          C       1.0 2013-02-19
# 1230          D       1.0 2002-08-20
# 32            Q       6.0 2012-06-15
# 436           B       3.0 2013-01-14
# 947           D       1.0 1999-12-28
# 1154          D       1.0 2002-08-20
# 710           D       1.0 2004-05-03
# 570           D       1.0 2011-12-30
# 460           D       1.0 2011-07-15
# 627           D       1.0 2012-04-26
# 862           D       1.0 2012-04-11
# 1066          D       1.0 2002-03-19
# 1175          D       1.0 2011-10-18
# 1053          D       1.0 2013-09-18
# 55            D       1.0 2014-09-22
# 526           D       1.0 2012-04-25
# 730           D       1.0 1995-04-11
# 1250          D       1.0 2011-10-18
# 860           D       1.0 2012-01-17
# 509           D       1.0 2008-07-29
# 821           D       1.0 2011-10-18
# 804           D       1.0 1998-03-25
# 210           D       1.0 2011-09-26
# 1135          A       1.0 2016-09-13
# 1153          D       1.0 2005-01-06
# 772           D       1.0 2007-06-26
# 517           D       1.0 1998-12-24
# 1272          D       1.0 2000-07-18
#
# [109 rows x 11 columns]

# %%
testset_4
# Out:
#       original_index State                Station Name (LEA)  \
# 14              1097    MA             TOPSFIELD POLICE DEPT
# 24               707    MA           NEW BEDFORD POLICE DEPT
# 35               573    MA                MILTON POLICE DEPT
# 60               340    MA               IPSWICH POLICE DEPT
# 99               947    MA         SHIRLEY POLICE DEPARTMENT
# 125              306    MA               HARWICH POLICE DEPT
# 134               70    MA               CHELSEA POLICE DEPT
# 138             1016    MA           SOUTHBRIDGE POLICE DEPT
# 153              843    MA                REVERE POLICE DEPT
# 159              830    MA                REVERE POLICE DEPT
# 161              379    MA              LAWRENCE POLICE DEPT
# 185              538    MA               METHUEN POLICE DEPT
# 214             1051    MA            STURBRIDGE POLICE DEPT
# 230             1113    MA          TYNGSBOROUGH POLICE DEPT
# 233              570    MA                MILTON POLICE DEPT
# 234              348    MA               IPSWICH POLICE DEPT
# 279              391    MA            LEOMINSTER POLICE DEPT
# 292             1304    MA              WEYMOUTH POLICE DEPT
# 331              566    MA                MILTON POLICE DEPT
# 339              227    MA            GLOUCESTER POLICE DEPT
# 343               33    MA                AUBURN POLICE DEPT
# 345              245    MA            GLOUCESTER POLICE DEPT
# 367             1048    MA            STURBRIDGE POLICE DEPT
# 375              536    MA               METHUEN POLICE DEPT
# 388             1182    MA               WAREHAM POLICE DEPT
# 392             1079    MA               TAUNTON POLICE DEPT
# 395             1046    MA           SPRINGFIELD POLICE DEPT
# 396              334    MA               IPSWICH POLICE DEPT
# 398              347    MA               IPSWICH POLICE DEPT
# 432              591    MA                MILTON POLICE DEPT
# ...              ...   ...                               ...
# 928              453    MA               MAYNARD POLICE DEPT
# 937              879    MA                REVERE POLICE DEPT
# 949              341    MA               IPSWICH POLICE DEPT
# 972              811    MA                REVERE POLICE DEPT
# 994              504    MA               METHUEN POLICE DEPT
# 1004             624    MA                MILTON POLICE DEPT
# 1014             913    MA                 SALEM POLICE DEPT
# 1017             488    MA               MEDFORD POLICE DEPT
# 1046             312    MA               HARWICH POLICE DEPT
# 1050             512    MA               METHUEN POLICE DEPT
# 1055             216    MA              FRANKLIN POLICE DEPT
# 1062             691    MA           NEW BEDFORD POLICE DEPT
# 1083            1163    MA               WAREHAM POLICE DEPT
# 1121            1135    MA               WALPOLE POLICE DEPT
# 1124             152    MA                   DOJ/USMS BOSTON
# 1136             936    MA              SCITUATE POLICE DEPT
# 1157             515    MA               METHUEN POLICE DEPT
# 1172             141    MA                   DOJ/USMS BOSTON
# 1183             470    MA               MEDFORD POLICE DEPT
# 1186             380    MA              LAWRENCE POLICE DEPT
# 1190             827    MA                REVERE POLICE DEPT
# 1191              55    MA            BROOKFIELD POLICE DEPT
# 1203            1092    MA             TEMPLETON POLICE DEPT
# 1216              16    MA                AUBURN POLICE DEPT
# 1221             915    MA  SALEM STATE COLLEGE POLICE HI_ED
# 1231             787    MA                QUINCY POLICE DEPT
# 1243             614    MA                MILTON POLICE DEPT
# 1271             961    MA              SOMERSET POLICE DEPT
# 1297             124    MA                DHS/ICE/HSI BOSTON
# 1307             726    MA           NORTHBRIDGE POLICE DEPT
#
#                    NSN                               Item Name  Quantity  \
# 14    1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 24    1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 35    5855-01-468-4169                    ILLUMINATOR,INFRARED         1
# 60    5985-00-106-6130                                 ANTENNA         4
# 99    1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 125   1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 134   1005-01-128-9936                   RIFLE,5.56 MILLIMETER         1
# 138   1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 153   1005-00-726-5655            PISTOL,CALIBER .45,AUTOMATIC         1
# 159   1670-01-338-9875                     HOLSTER,HARNESS PAR         4
# 161   1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 185   1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 214   1005-01-128-9936                   RIFLE,5.56 MILLIMETER         1
# 230   1005-01-128-9936                   RIFLE,5.56 MILLIMETER         1
# 233   5855-01-468-4169                    ILLUMINATOR,INFRARED         1
# 234   1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 279   1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 292   1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 331   5855-01-468-4169                    ILLUMINATOR,INFRARED         1
# 339   2320-01-107-7155                           TRUCK,UTILITY         1
# 343   1005-00-726-5655            PISTOL,CALIBER .45,AUTOMATIC         1
# 345   5855-01-228-0939                     NIGHT VISION GOGGLE         1
# 367   1005-01-128-9936                   RIFLE,5.56 MILLIMETER         1
# 375   1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 388   1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 392   1005-00-856-6885                   RIFLE,5.56 MILLIMETER         1
# 395   1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 396   1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 398   5855-01-524-4314                           SIGHT,THERMAL         1
# 432   5855-01-468-4169                    ILLUMINATOR,INFRARED         1
# ...                ...                                     ...       ...
# 928   1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 937   1005-00-726-5655            PISTOL,CALIBER .45,AUTOMATIC         1
# 949   5855-01-490-7093                    ILLUMINATOR,INFRARED         8
# 972   5855-00-629-5327  NIGHT VISION SIGHT CREW SERVED WEAPONS         1
# 994   1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1004  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1014  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1017  1005-00-921-5004                      MAGAZINE,CARTRIDGE       200
# 1046  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1050  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1055  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1062  1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 1083  1005-01-144-1492                     SPRING,HAMMER              22
# 1121  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1124  4240-DS-GOG-GLES                          SAFETY GOGGLES        15
# 1136  2320-01-107-7155                           TRUCK,UTILITY         1
# 1157  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1172  6230-01-572-8340                         SEARCHLIGHT SET         2
# 1183  1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 1186  1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 1190  8475-01-190-8165                     JAW RECEIVER                8
# 1191  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1203  1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 1216  1005-00-726-5655            PISTOL,CALIBER .45,AUTOMATIC         1
# 1221  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1231  1005-00-073-9421                   RIFLE,5.56 MILLIMETER         1
# 1243  5855-01-468-4169                    ILLUMINATOR,INFRARED         1
# 1271  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
# 1297  6510-01-541-8121                     BANDAGE,ABDOMINAL          99
# 1307  1005-00-589-1271                   RIFLE,7.62 MILLIMETER         1
#
#         UI  Acquisition Value DEMIL Code  DEMIL IC  Ship Date
# 14    Each             499.00          D       1.0 2002-09-09
# 24    Each             499.00          D       1.0 2012-01-17
# 35    Each             776.79          D       1.0 2012-12-20
# 60    Each             861.80          D       1.0 2014-03-11
# 99    Each             138.00          D       1.0 1999-12-28
# 125   Each             138.00          D       1.0 1996-06-26
# 134   Each             749.00          D       1.0 2014-09-22
# 138   Each             499.00          D       1.0 2011-11-30
# 153   Each              58.71          D       1.0 2011-12-23
# 159   Each              41.44          B       3.0 2010-08-25
# 161   Each             499.00          D       1.0 2012-04-26
# 185   Each             499.00          D       1.0 2008-07-29
# 214   Each             749.00          D       1.0 2014-09-22
# 230   Each             749.00          D       1.0 2014-12-01
# 233   Each             776.79          D       1.0 2012-12-20
# 234   Each             138.00          D       1.0 2007-06-21
# 279   Each             499.00          D       1.0 1998-03-25
# 292   Each             138.00          D       1.0 2000-12-18
# 331   Each             776.79          D       1.0 2012-12-20
# 339   Each           41061.00          Q       6.0 2012-06-08
# 343   Each              58.71          D       1.0 2012-04-12
# 345   Each            6000.00          F       1.0 2012-01-18
# 367   Each             749.00          D       1.0 2014-09-22
# 375   Each             499.00          D       1.0 2008-07-29
# 388   Each             499.00          D       1.0 2005-12-28
# 392   Each             120.00          D       1.0 2011-10-18
# 395   Each             138.00          D       1.0 1998-04-24
# 396   Each             499.00          D       1.0 2007-06-21
# 398   Each           11999.00          D       1.0 2016-11-10
# 432   Each             776.79          D       1.0 2012-07-18
# ...    ...                ...        ...       ...        ...
# 928   Each             499.00          D       1.0 2013-02-27
# 937   Each              58.71          D       1.0 2011-12-23
# 949   Each            1496.40          D       1.0 2012-11-21
# 972   Each            3433.00          F       1.0 2011-02-12
# 994   Each             138.00          D       1.0 1999-12-27
# 1004  Each             138.00          D       1.0 2012-03-20
# 1014  Each             138.00          D       1.0 1995-05-16
# 1017  Each              12.30          D       1.0 2016-12-19
# 1046  Each             138.00          D       1.0 1996-06-26
# 1050  Each             138.00          D       1.0 1999-12-28
# 1055  Each             138.00          D       1.0 2002-03-19
# 1062  Each             499.00          D       1.0 2012-01-17
# 1083  Each               0.33          B       3.0 2013-02-19
# 1121  Each             138.00          D       1.0 2001-02-14
# 1124  Each             260.00          A       NaN 2014-04-11
# 1136  Each           41061.00          Q       6.0 2011-12-15
# 1157  Each             138.00          D       1.0 1999-12-27
# 1172  Each              28.92          A       1.0 2014-04-11
# 1183  Each             499.00          D       1.0 2006-02-16
# 1186  Each             499.00          D       1.0 2012-04-26
# 1190  Each              11.51          B       3.0 2011-09-18
# 1191  Each             138.00          D       1.0 2001-02-14
# 1203  Each             499.00          D       1.0 2007-06-21
# 1216  Each              58.71          D       1.0 2012-04-12
# 1221  Each             138.00          D       1.0 2008-11-12
# 1231  Each             499.00          D       1.0 2005-12-05
# 1243  Each             776.79          D       1.0 2012-07-18
# 1271  Each             138.00          D       1.0 2003-06-21
# 1297  Each              13.42          A       1.0 2017-03-22
# 1307  Each             138.00          D       1.0 2003-06-25
#
# [109 rows x 11 columns]

# %% [markdown]
# # Clustering Code

# %%
def rescale_list(mylist, new_max, new_min, current_max, current_min):
    X_scaled = []
    for X in mylist:
        X_scaled.append(((new_max-new_min)*(X - current_min))/(current_max-current_min)+new_min)
        
    return(X_scaled)

# %%
def evaluate_clusters(X,max_clusters):
    error = np.zeros(max_clusters+1)
    error[0] = 0;
    for k in range(1,max_clusters+1):
        kmeans = KMeans(init='k-means++', n_clusters=k, n_init=20)
        kmeans.fit_predict(X)
        error[k] = kmeans.inertia_
    
    plt.figure(figsize=(20,10))
    plt.plot(range(1,len(error)),error[1:])
    plt.xlabel('Number of clusters', {'fontsize':20})
    plt.xticks(size=20)
    plt.ylabel('Error', {'fontsize':20})
    plt.yticks(size=20)

# %%
def sc_evaluate_clusters(X,max_clusters):
    s = np.zeros(max_clusters+1)
    s[0] = 0;
    s[1] = 0;
    for k in range(2,max_clusters+1):
        kmeans = KMeans(init='k-means++', n_clusters=k, n_init=20)
        kmeans.fit_predict(X)
        s[k] = metrics.silhouette_score(X,kmeans.labels_,metric='euclidean')
        
    plt.figure(figsize=(20,10))
    plt.plot(range(2,len(s)),s[2:])
    plt.xlabel('Number of clusters', {'fontsize':20})
    plt.xticks(size=20)
    plt.ylabel('Silhouette Score', {'fontsize':20})
    plt.yticks(size=20)

# %%
def sc_evaluate_clusters_heir(Z,data,max_clusters):
    s = np.zeros(max_clusters+1)
    for k in range(2,max_clusters+1):
        clusters = hierarchy.fcluster(Z, k, criterion='maxclust')
        s[k] = metrics.silhouette_score(data,clusters,metric='euclidean')
 
    plt.figure(figsize=(20,10))
    plt.xlabel('Number of clusters', {'fontsize':20})
    plt.ylabel('Silhouette Score', {'fontsize':20})
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.plot(range(2,len(s)),s[2:])

# %%
def sc_evaluate_clusters_gmm(X,max_clusters):
    s = np.zeros(max_clusters+1)
    s[0] = 0;
    s[1] = 0;
    for k in range(2,max_clusters+1):
        gmm = mixture.GaussianMixture(n_components=k, covariance_type='full')
        gmm.fit(X)
        s[k] = metrics.silhouette_score(X,gmm.predict(X),metric='euclidean')
        
    plt.figure(figsize=(20,10))
    plt.plot(range(2,len(s)),s[2:])
    plt.xlabel('Number of clusters', {'fontsize':20})
    plt.xticks(size=20)
    plt.ylabel('Silhouette Score', {'fontsize':20})
    plt.yticks(size=20)

# %%
def sc_evaluate_clusters_gmm(X,max_clusters):
    s = np.zeros(max_clusters+1)
    s[0] = 0;
    s[1] = 0;
    for k in range(2,max_clusters+1):
        gmm = mixture.GaussianMixture(n_components=k, covariance_type='full')
        gmm.fit(X)
        s[k] = metrics.silhouette_score(X,gmm.predict(X),metric='euclidean')
        
    plt.figure(figsize=(20,10))
    plt.plot(range(2,len(s)),s[2:])
    plt.xlabel('Number of clusters', {'fontsize':20})
    plt.xticks(size=20)
    plt.ylabel('Silhouette Score', {'fontsize':20})
    plt.yticks(size=20)

# %%
def list_to_string(review_list):
    new_list = []
    
    for rest_review in review_list:
        new_list.append(" ".join(str(x) for x in rest_review))
    
    return new_list

# %% [markdown]
# # Kmeans

# %%
Feature_vector = Master_training.copy()
del Feature_vector['Ship Date']
del Feature_vector['State']
del Feature_vector['original_index']
#del Feature_vector['DEMIL Code']
#del Feature_vector['UI']
#del Feature_vector['NSN']
print(type(Feature_vector['Station Name (LEA)'][0]))
print(type(Feature_vector['Item Name'][0]))
print(type(Feature_vector['Quantity'][0]))
print(type(Feature_vector['UI'][0]))
print(type(Feature_vector['Acquisition Value'][0]))
print(type(Feature_vector['DEMIL Code'][0]))
print(type(Feature_vector['DEMIL IC'][0]))
Feature_vector
# Out:
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'numpy.float64'>
# <class 'str'>
# <class 'numpy.float64'>
#                 Station Name (LEA)               NSN  \
# 902          WATERTOWN POLICE DEPT  1005-00-589-1271
# 44         NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 1189               REHOBOTH POLICE  2355-01-553-4634
# 37              NORTON POLICE DEPT  1005-00-589-1271
# 27             MEDFORD POLICE DEPT  1005-00-073-9421
# 193        SOUTHBRIDGE POLICE DEPT  1005-00-726-5655
# 1057            MONSON POLICE DEPT  1005-00-589-1271
# 824         STURBRIDGE POLICE DEPT  1005-01-128-9936
# 472        NEW BEDFORD POLICE DEPT  1005-00-073-9421
# 22             WAREHAM POLICE DEPT  5360-00-979-3931
# 789             REVERE POLICE DEPT  8475-01-311-9630
# 553             MILTON POLICE DEPT  5855-01-468-4169
# 208            CLINTON POLICE DEPT  1240-01-411-1265
# 1242           WEBSTER POLICE DEPT  1005-00-073-9421
# 647     WESTPORT POLICE DEPARTMENT  5855-01-447-8992
# 696            IPSWICH POLICE DEPT  1240-01-411-1265
# 657             REVERE POLICE DEPT  1005-00-726-5655
# 1187  PLYMOUTH COUNTY SHERIFF DEPT  2520-01-474-7051
# 1127         FAIRHAVEN POLICE DEPT  1005-00-073-9421
# 615          FAIRHAVEN POLICE DEPT  1005-00-073-9421
# 850            METHUEN POLICE DEPT  1005-01-484-8000
# 1077    WESTPORT POLICE DEPARTMENT  1005-00-073-9421
# 91            CHARLTON POLICE DEPT  1005-00-073-9421
# 156             MILTON POLICE DEPT  5855-01-468-4169
# 514             MILTON POLICE DEPT  5855-01-468-4169
# 924             REVERE POLICE DEPT  5855-00-629-5327
# 869            MILFORD POLICE DEPT  1005-00-589-1271
# 659         GLOUCESTER POLICE DEPT  5855-01-228-0939
# 239             AUBURN POLICE DEPT  1005-00-073-9421
# 1197           MEDFORD POLICE DEPT  1005-00-921-5483
# ...                            ...               ...
# 116               LYNN POLICE DEPT  1005-01-128-9936
# 656         SWAMPSCOTT POLICE DEPT  1005-00-589-1271
# 633                REHOBOTH POLICE  1005-00-073-9421
# 173            METHUEN POLICE DEPT  1005-00-589-1271
# 266          TEMPLETON POLICE DEPT  1005-00-073-9421
# 167            WAREHAM POLICE DEPT  1005-01-233-8529
# 299             AUBURN POLICE DEPT  1005-00-726-5655
# 75           MANSFIELD POLICE DEPT  1005-00-073-9421
# 885               LYNN POLICE DEPT  1005-01-128-9936
# 79             EVERETT POLICE DEPT  1005-00-589-1271
# 1176         FAIRHAVEN POLICE DEPT  1005-00-073-9421
# 88             GRAFTON POLICE DEPT  1005-00-073-9421
# 1091           MBTA TRANSIT POLICE  1005-00-073-9421
# 1196             SALEM POLICE DEPT  1005-00-589-1271
# 977            CHELSEA POLICE DEPT  1005-01-128-9936
# 816        SOUTHBRIDGE POLICE DEPT  1005-00-073-9421
# 477             REVERE POLICE DEPT  1005-00-726-5655
# 114          WELLESLEY POLICE DEPT  8465-01-465-2144
# 865         BARNSTABLE POLICE DEPT  5855-01-034-3845
# 467           SOMERSET POLICE DEPT  1005-00-589-1271
# 1085           WAREHAM POLICE DEPT  1005-01-484-8000
# 469       TYNGSBOROUGH POLICE DEPT  1005-00-311-5394
# 399     HINSDALE POLICE DEPARTMENT  1005-00-856-6885
# 228    WESTFIELD POLICE DEPARTMENT  1005-00-073-9421
# 950             NORTON POLICE DEPT  1005-00-589-1271
# 881     WESTPORT POLICE DEPARTMENT  5855-01-447-8992
# 276           LAWRENCE POLICE DEPT  1005-00-073-9421
# 586          LEXINGTON POLICE DEPT  1005-00-073-9421
# 133            WAREHAM POLICE DEPT  1005-00-073-9421
# 699          TEMPLETON POLICE DEPT  1005-00-589-1271
#
#                                    Item Name  Quantity    UI  \
# 902                    RIFLE,7.62 MILLIMETER         1  Each
# 44                     RIFLE,5.56 MILLIMETER         1  Each
# 1189                  MINE RESISTANT VEHICLE         1  Each
# 37                     RIFLE,7.62 MILLIMETER         1  Each
# 27                     RIFLE,5.56 MILLIMETER         1  Each
# 193             PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 1057                   RIFLE,7.62 MILLIMETER         1  Each
# 824                    RIFLE,5.56 MILLIMETER         1  Each
# 472                    RIFLE,5.56 MILLIMETER         1  Each
# 22                SPRING,HELICAL,COMPRESSION        10  Each
# 789                      VISOR,FLYERS HELMET         4  Each
# 553                     ILLUMINATOR,INFRARED         1  Each
# 208                             SIGHT,REFLEX         5  Each
# 1242                   RIFLE,5.56 MILLIMETER         1  Each
# 647                     ILLUMINATOR,INFRARED         1  Each
# 696                             SIGHT,REFLEX         1  Each
# 657             PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 1187        TRANSMISSION,HYDRAULIC,VEHICULAR         1  Each
# 1127                   RIFLE,5.56 MILLIMETER         1  Each
# 615                    RIFLE,5.56 MILLIMETER         1  Each
# 850                               SIGHT,REAR        10  Each
# 1077                   RIFLE,5.56 MILLIMETER         1  Each
# 91                     RIFLE,5.56 MILLIMETER         1  Each
# 156                     ILLUMINATOR,INFRARED         1  Each
# 514                     ILLUMINATOR,INFRARED         1  Each
# 924   NIGHT VISION SIGHT CREW SERVED WEAPONS         1  Each
# 869                    RIFLE,7.62 MILLIMETER         1  Each
# 659                      NIGHT VISION GOGGLE         1  Each
# 239                    RIFLE,5.56 MILLIMETER         1  Each
# 1197               SHOTGUN,12 GAGE,RIOT TYPE         1  Each
# ...                                      ...       ...   ...
# 116                    RIFLE,5.56 MILLIMETER         1  Each
# 656                    RIFLE,7.62 MILLIMETER         1  Each
# 633                    RIFLE,5.56 MILLIMETER         1  Each
# 173                    RIFLE,7.62 MILLIMETER         1  Each
# 266                    RIFLE,5.56 MILLIMETER         1  Each
# 167          BARREL AND FRONT SIGHT ASSEMBLY         2  Each
# 299             PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 75                     RIFLE,5.56 MILLIMETER         1  Each
# 885                    RIFLE,5.56 MILLIMETER         1  Each
# 79                     RIFLE,7.62 MILLIMETER         1  Each
# 1176                   RIFLE,5.56 MILLIMETER         1  Each
# 88                     RIFLE,5.56 MILLIMETER         1  Each
# 1091                   RIFLE,5.56 MILLIMETER         1  Each
# 1196                   RIFLE,7.62 MILLIMETER         1  Each
# 977                    RIFLE,5.56 MILLIMETER         1  Each
# 816                    RIFLE,5.56 MILLIMETER         1  Each
# 477             PISTOL,CALIBER .45,AUTOMATIC         1  Each
# 114         POUCH,BANDOLEER AMMO,6 MAGAZINES         1  Each
# 865      IMAGE INTENSIFIER TUBE,NIGHT VISION         9  Each
# 467                    RIFLE,7.62 MILLIMETER         1  Each
# 1085                              SIGHT,REAR         2  Each
# 469                      TOOL,BORE ALIGNMENT         1  Each
# 399                    RIFLE,5.56 MILLIMETER         1  Each
# 228                    RIFLE,5.56 MILLIMETER         1  Each
# 950                    RIFLE,7.62 MILLIMETER         1  Each
# 881                     ILLUMINATOR,INFRARED         1  Each
# 276                    RIFLE,5.56 MILLIMETER         1  Each
# 586                    RIFLE,5.56 MILLIMETER         1  Each
# 133                    RIFLE,5.56 MILLIMETER         1  Each
# 699                    RIFLE,7.62 MILLIMETER         1  Each
#
#       Acquisition Value DEMIL Code  DEMIL IC
# 902              138.00          D       1.0
# 44               499.00          D       1.0
# 1189          658000.00          C       1.0
# 37               138.00          D       1.0
# 27               499.00          D       1.0
# 193               58.71          D       1.0
# 1057             138.00          D       1.0
# 824              749.00          D       1.0
# 472              499.00          D       1.0
# 22                 0.27          B       3.0
# 789              114.55          B       3.0
# 553              776.79          D       1.0
# 208              315.00          D       1.0
# 1242             499.00          D       1.0
# 647             1038.00          D       1.0
# 696              315.00          D       1.0
# 657               58.71          D       1.0
# 1187            1027.50          Q       6.0
# 1127             499.00          D       1.0
# 615              499.00          D       1.0
# 850               58.97          D       1.0
# 1077             499.00          D       1.0
# 91               499.00          D       1.0
# 156              776.79          D       1.0
# 514              776.79          D       1.0
# 924             3433.00          F       1.0
# 869              138.00          D       1.0
# 659             6000.00          F       1.0
# 239              499.00          D       1.0
# 1197             108.00          D       1.0
# ...                 ...        ...       ...
# 116              749.00          D       1.0
# 656              138.00          D       1.0
# 633              499.00          D       1.0
# 173              138.00          D       1.0
# 266              499.00          D       1.0
# 167              115.00          D       1.0
# 299               58.71          D       1.0
# 75               499.00          D       1.0
# 885              749.00          D       1.0
# 79               138.00          D       1.0
# 1176             499.00          D       1.0
# 88               499.00          D       1.0
# 1091             499.00          D       1.0
# 1196             138.00          D       1.0
# 977              749.00          D       1.0
# 816              499.00          D       1.0
# 477               58.71          D       1.0
# 114                8.37          A       1.0
# 865             3366.00          F       1.0
# 467              138.00          D       1.0
# 1085              58.97          D       1.0
# 469              106.14          B       3.0
# 399              120.00          D       1.0
# 228              499.00          D       1.0
# 950              138.00          D       1.0
# 881             1038.00          D       1.0
# 276              499.00          D       1.0
# 586              499.00          D       1.0
# 133              499.00          D       1.0
# 699              138.00          D       1.0
#
# [873 rows x 8 columns]

# %%
yup = ['nice', 'open', 'bar', 'with','great', 'view', 'of', 'the']
yup
# Out:
# ['nice', 'open', 'bar', 'with', 'great', 'view', 'of', 'the']

# %%
list_to_string(yup)
# Out:
# ['nice', 'open', 'bar', 'with', 'great', 'view', 'of', 'the']

# %%
#Creates error for kmeans
evaluate_clusters(Feature_vector, 25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-7e3292be4be7> in <module>()
#       1 #Creates error for kmeans
# ----> 2 evaluate_clusters(Feature_vector, 25)
#
# <ipython-input-17-276af8cfc4dd> in evaluate_clusters(X, max_clusters)
#       4     for k in range(1,max_clusters+1):
#       5         kmeans = KMeans(init='k-means++', n_clusters=k, n_init=20)
# ----> 6         kmeans.fit_predict(X)
#       7         error[k] = kmeans.inertia_
#       8
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit_predict(self, X, y)
#     915             Index of the cluster each sample belongs to.
#     916         """
# --> 917         return self.fit(X).labels_
#     918
#     919     def fit_transform(self, X, y=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y)
#     885         """
#     886         random_state = check_random_state(self.random_state)
# --> 887         X = self._check_fit_data(X)
#     888
#     889         self.cluster_centers_, self.labels_, self.inertia_, self.n_iter_ = \
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in _check_fit_data(self, X)
#     856     def _check_fit_data(self, X):
#     857         """Verify that the number of samples given is larger than k"""
# --> 858         X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32])
#     859         if X.shape[0] < self.n_clusters:
#     860             raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'RIFLE,7.62 MILLIMETER'

# %%
#Creates Silhouette Score for kmeans
sc_evaluate_clusters(Feature_vector,25)

# %%
# Creates kmeans fit, labeling, and centroids
kmeans = KMeans(init='k-means++', n_clusters=5, n_init=100)
kmeans.fit_predict(Feature_vector)
kmeans_centroids = kmeans.cluster_centers_
kmeans_labels = kmeans.labels_

#stem_data['kmean_cluster'] = kmeans_labels

# %%
# Generates Cluster Graph
plt.title('Las Vegas Yelp Restuarants 10 Reviews: colors are clusters assigned by k-means.', {'fontsize':28})
plt.rcParams["figure.figsize"] = (20,20)
plt.xticks(size=20)
plt.yticks(size=20)
cols = [matplotlib_colors[p] for p in kmeans_labels]
plt.scatter(stem_data['rescale_longitude'], stem_data['rescale_latitude'], s=50, c=cols)
plt.scatter(kmeans_centroids[:,0]*10, kmeans_centroids[:,1]*10, s = 250, c='k')
plt.show()

# %% [markdown]
# # Hierarchy

# %%
#Creates Silhouette Score for hierarchy
Z = hierarchy.linkage(Feature_vector, method='ward', metric='euclidean')
sc_evaluate_clusters_heir(Z,Feature_vector,25)

# %%
#Creates Dendogram
plt.figure(figsize=(20,15))
plt.xticks(size=20)
plt.yticks(size=20)
R = hierarchy.dendrogram(Z, p=4, truncate_mode='level', show_leaf_counts=True)

# %%
# Creates hierarchy fit and labeling
hier_labels = hierarchy.fcluster(Z, 3, criterion='maxclust')
#stem_data['hier_cluster'] = hier_labels

# %%
# Creates hierarchy centroids
hier_groups = stem_data.groupby('hier_cluster')
hier_centroid = np.zeros(shape=(max(hier_labels),102))

for hier_cluster_num, hier_groups_data in hier_groups:
    hier_centroid[hier_cluster_num-1] = hier_groups_data['Feature_vector'].mean()

# %%
# Generates Cluster Graph
plt.title('Las Vegas Yelp Restuarants 10 Reviews: colors are clusters assigned by hierarchy.', {'fontsize':28})
plt.rcParams["figure.figsize"] = (20,20)
plt.xticks(size=20)
plt.yticks(size=20)
cols = [matplotlib_colors[p-1] for p in hier_labels]
plt.scatter(stem_data['rescale_longitude'], stem_data['rescale_latitude'], s=50, c=cols)
plt.scatter(hier_centroid[:,0]*10, hier_centroid[:,1]*10, s = 250, c='k')
plt.show()

# %% [markdown]
# ## GMM

# %%
#Creates Silhouette Score for GMM
sc_evaluate_clusters_gmm(Feature_vector,25)

# %%
# Creates gmm fit, labeling, and centroids
gmm = mixture.GaussianMixture(n_components=9, covariance_type='full')
gmm.fit(Feature_vector)

gmm_labels = gmm.predict(Feature_vector)
gmm_centroids = gmm.means_

#stem_data['gmm_cluster'] = gmm_labels

# %%
# Generates Cluster Graph
plt.rcParams["figure.figsize"] = (20,20)
plt.title('Las Vegas Yelp Restuarants 10 Reviews: colors are clusters assigned by GMM.', {'fontsize':28})
plt.xticks(size=20)
plt.yticks(size=20)
colors = [matplotlib_colors[p] for p in gmm_labels]
_ = plt.scatter(stem_data['rescale_longitude'], stem_data['rescale_latitude'], color=colors, s=50, alpha=0.8)
plt.scatter(gmm_centroids[:,0]*10, gmm_centroids[:,1]*10, s = 250, c='k')
